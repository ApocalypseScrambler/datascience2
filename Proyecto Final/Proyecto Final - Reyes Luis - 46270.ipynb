# %% [markdown]
# <h1 style="font-family:Times;text-align:center;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;border-radius:8px">Bank Customer Churn</h1>

# %% [markdown]
# <style>
#       .img-container {
#         text-align: center;
#       }
# </style>
# <div class="img-container"> <!-- Block parent element -->
#       <img src="https://s16353.pcdn.co/wp-content/uploads/2018/06/Churn.png" alt="Bank Customer Churn">
# </div>

# %% [markdown]
# <h1 style="font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;border-radius:8px">Indice</h1>

# %% [markdown]
# * [1. Introducción](#1)
#     * [1.1 Presentación](#1-1)
#     * [1.2 Librerias](#1-2)
#     * [1.3 Importación Dataset](#1-3)
#     * [1.4 Columnas](#1-4)
# * [2. Exploratory Data Analysis (EDA)](#2)
#     * [2.1 Missing Data](#2-1)
#     * [2.2 Análisis de Variables](#2-2)
# * [3. Variable Target](#3)
#     * [3.1 Information Value](#3-1)
#     * [3.2 Arbol de Decisiones](#3-2)
# * [4. Regresión Logística](#4)
#     * [4.1 Modelo 1](#4-1)
#         * [4.1.1 Matriz de Confusión](#4-1-1)
#         * [4.1.2 Validación Modelo 1](#4-1-2)
#         * [4.1.3 Métricas de Entrenamiento y Prueba](#4-1-3)
#         * [4.1.4 K-fold Cross-Validation - Validación Cruzada](#4-1-4)
#         * [4.1.5 AUC - Curva ROC](#4-1-5)
#     * [4.2 Modelo 2](#4-2)
#         * [4.1.1 Matriz de Confusión](#4-2-1)
#         * [4.1.2 Validación Modelo 2](#4-2-2)
#         * [4.1.3 Métricas de Entrenamiento y Prueba](#4-2-3)
#         * [4.1.4 K-fold Cross-Validation - Validación Cruzada](#4-2-4)
#         * [4.1.5 AUC - Curva ROC](#4-2-5)
#     * [4.3 Regresión Logística - Conclusiones](#4-3)
# * [5. RandomForest](#5)
#     * [5.1 Modelo Random Forest](#5-1)
#     * [5.2 Features Importances](#5-2)
#     * [5.3 Ajuste de Hiperparametros](#5-3)
#     * [5.4 RandomForest Nuevo Modelo Ajustado](#5-4)
#     * [5.5 AUC/ROC RandomForest](#5-5)
#     * [5.6 Validación Cruzada RandomForest](#5-6)
#     * [5.6 Conclusiones RandomForest](#5-7)
# * [6. Modelo KNN - K-Nearest Neighbors](#6)
#     * [6.1 Validación Cruzada KNN - K-Nearest Neighbors](#6-1)
#     * [6.2 Conclusiones KNN - K-Nearest Neighbors](#6-2)
# * [7. Feature Engineering](#7)
#     * [7.1 Principal Component Analysis (PCA)](#7-1)
#     * [7.2 Kernel PCA](#7-2)
#     * [7.3 Ánalisis Factorial](#7-3)
#     * [7.4 Resultados en Gráficos](#7-4)
#     * [7.5 Conclusiones](#7-5)
# * [8. Conclusión Final](#8)
#     * [8.1 Variables Relevantes](#8-1)
#     * [8.2 Desempeño del Modelo](#8-2)
#     * [8.3 Conclusión](#8-3)
#     * [8.4 Recomendaciones](#8-4)
#     * [8.5 Resumen](#8-5)

# %% [markdown]
# <a id="1"></a>
# <h1 style="font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;border-radius:8px">Introduccion</h1>

# %% [markdown]
# <a id="1-1"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Presentación</h3>
#
# <h5 style="text-align:left;text-decoration:underline;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;">Motivación:</h5>
#
# La motivación detrás de este proyecto de análisis de datos es abordar un desafío crítico en la industria bancaria: la retención de clientes. La retención de clientes es fundamental para el éxito a largo plazo de cualquier institución financiera, ya que es más costoso adquirir nuevos clientes que retener a los existentes. Al comprender los factores que llevan a la pérdida de clientes, el banco puede tomar medidas proactivas para retener a sus clientes y, en última instancia, mejorar su rentabilidad.
#
# <h5 style="text-align:left;text-decoration:underline;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;">Audiencia:</h5>
#
# La audiencia principal de este proyecto incluye la alta dirección del banco, gerentes de relaciones con clientes, analistas de datos y equipos de marketing. Además, los resultados y las recomendaciones derivadas de este análisis pueden ser de interés para otros profesionales del sector financiero que enfrentan desafíos similares de retención de clientes.
#
# <h5 style="text-align:left;text-decoration:underline;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;">Preguntas/Hipótesis:</h5>
#
# Algunas preguntas clave que guiaron este proyecto incluyen:
#
# ¿Cuáles son los factores más influyentes en la pérdida de clientes en el banco?
# ¿Existen patrones demográficos que se correlacionen con la retención de clientes?
# ¿El comportamiento de transacciones, como la frecuencia de uso de servicios bancarios, afecta la retención de clientes?
# ¿Pueden las campañas de marketing o incentivos especiales impactar en la retención de clientes?
#
# <h5 style="text-align:left;text-decoration:underline;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;">Definición de Objetivo:</h5>
#
# El objetivo principal de este proyecto es desarrollar un modelo predictivo que pueda identificar a los clientes que tienen mayor probabilidad de dejar de hacer negocios con el banco en un futuro cercano. Esto permitirá al banco tomar medidas proactivas, como ofrecer incentivos o mejorar la atención al cliente, para retener a esos clientes. Además, el proyecto tiene como objetivo proporcionar una comprensión más profunda de los factores subyacentes que contribuyen a la pérdida de clientes.
#
# <h5 style="text-align:left;text-decoration:underline;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;">Contexto Comercial:</h5>
#
# En el contexto comercial, la retención de clientes es fundamental para la rentabilidad y la sostenibilidad a largo plazo del banco. Perder clientes implica una disminución en los ingresos y puede tener un impacto significativo en la reputación de la institución. El banco busca maximizar la retención de clientes a través de una estrategia de gestión de relaciones efectiva.
#
# <h5 style="text-align:left;text-decoration:underline;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;">Problema Comercial:</h5>
#
# El problema comercial clave que aborda este proyecto es la pérdida de clientes. La institución financiera enfrenta una tasa de rotación de clientes preocupante y busca identificar las causas fundamentales de esta pérdida y, en última instancia, reducirla. La retención de clientes no solo es esencial para el crecimiento del banco, sino que también tiene un impacto directo en la satisfacción del cliente y su percepción de la marca.
#
# <h5 style="text-align:left;text-decoration:underline;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;">Contexto Analítico:</h5>
#
# El contexto analítico de este proyecto se centra en el análisis de datos, el modelado predictivo y la minería de datos. Se utilizarán técnicas avanzadas de aprendizaje automático y estadísticas para analizar el conjunto de datos de clientes y desarrollar un modelo que pueda predecir la probabilidad de que un cliente deje de ser cliente del banco en un período de tiempo determinado. Además, se llevará a cabo un análisis de características para identificar los factores clave que influyen en la retención de clientes.
#
# En resumen, este proyecto de análisis de datos tiene como objetivo proporcionar una visión profunda de los factores que influyen en la retención de clientes en el banco y desarrollar un modelo predictivo que permita tomar medidas proactivas para retener a los clientes. El enfoque se basa en técnicas analíticas avanzadas y tiene un claro impacto en la estrategia comercial del banco.

# %% [markdown]
# <a id="1-2"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Librerias</h3>

# %%
# Comencemos importando nuestras librerias
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Librerías para arboles de decision 
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier, plot_tree

# Librería matriz de confusión
from sklearn.metrics import confusion_matrix
# Librería para curva de ROC
from sklearn.metrics import roc_curve, roc_auc_score
# Librerias para regresión logística
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold, cross_val_score, GridSearchCV, RandomizedSearchCV
# LabelEncoder
from sklearn.preprocessing import LabelEncoder
# RandomForest
from sklearn.metrics import classification_report, precision_recall_fscore_support, auc
from sklearn.ensemble import RandomForestClassifier
# Modelo KNN - K-Nearest Neighbors
from sklearn.neighbors import KNeighborsClassifier

# Feature Engineering
from sklearn.decomposition import PCA
from sklearn.decomposition import KernelPCA
from factor_analyzer import FactorAnalyzer
# En caso de fallar la libreria de Ánalisis Factorial
#pip install factor_analyzer

pd.options.display.float_format = '{:.2f}'.format
import warnings
warnings.filterwarnings("ignore")
sns.set_style('whitegrid') 
sns.set(font_scale = 1)

# %% [markdown]
# <a id="1-3"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Importación Dataset</h3>

# %% [markdown]
# *Importemos nuestra muestra de datos para comenzar el ánalisis*

# %%
url = 'https://raw.githubusercontent.com/ApocalypseScrambler/datascience2/main/Credit%20Card%20customers/BankChurners.csv'

# Levanto el archivo 
df = pd.read_csv(url,sep = ',')

# Vamos algunos de sus datos
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Credit_Limit  Total_Revolving_Bal  Avg_Open_To_Buy  \
# 0              39  ...      12691.00                  777         11914.00
# ...

# %%
#Elimino columnas que no serán analizadas por no contar con datos relevantes
df = df.drop(['Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1', 'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'], axis = 1)

# %%
# Veamos cantidad de registros y columnas
df.shape
# Out:
# (10127, 21)

# %%
#Descripción de las columnas
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  object
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             10127 non-null  object
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
# ...

# %% [markdown]
# <a id="1-4"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Columnas</h3>

# %% [markdown]
# *A Continuación veremos cada una de las variables que contaremos para el ánalisis y su definición*

# %% [markdown]
# * <b><u>CLIENTNUM:</u></b> Número de cliente. Identificador único del cliente titular de la cuenta.
# * <b><u>Attrition_Flag:</u></b> variable de evento interno (actividad del cliente): si la cuenta está cerrada, entonces 1, si no, 0.
# * <b><u>Customer_Age:</u></b> Variable demográfica - Edad del cliente en años
# * <b><u>Gender:</u></b> Variable demográfica - M=Hombre, F=Mujer
# * <b><u>Dependent_count:</u></b> Variable demográfica - Número de dependientes
# * <b><u>Education_Level:</u></b> Variable demográfica - Calificación educativa del titular de la cuenta (ejemplo: escuela secundaria, graduado universitario, etc.)
# * <b><u>Marital_Status:</u></b> variable demográfica: casado, soltero, divorciado, desconocido
# * <b><u>Income_Category:</u></b> Variable demográfica - Categoría de ingreso anual del titular de la cuenta (< 40K, 40K - 60K, 60K - 80K, 80K-120K, >)
# * <b><u>Card_Category:</u></b> Variable de producto - Tipo de tarjeta (Blue, Silver, Gold, Platinum)
# * <b><u>Months_on_book:</u></b> Periodo de relación con el banco
# * <b><u>Total_Relationship_Count:</u></b> Número total. de productos en poder del cliente
# * <b><u>Months_Inactive_12_mon:</u></b> No. de meses inactivos en los últimos 12 meses
# * <b><u>Contacts_Count_12_mon:</u></b> No. de contactos en los últimos 12 meses
# * <b><u>Credit_Limit:</u></b> Límite de crédito en la tarjeta de crédito
# * <b><u>Total_Revolving_Bal:</u></b> Saldo rotativo total de la tarjeta de crédito
# * <b><u>Avg_Open_To_Buy:</u></b> Línea de crédito abierta para comprar (promedio de los últimos 12 meses)
# * <b><u>Total_Amt_Chng_Q4_Q1:</u></b> Cambio en el monto de la transacción (Q4 sobre Q1)
# * <b><u>Total_Trans_Amt:</u></b> Monto total de la transacción (últimos 12 meses)
# * <b><u>Total_Trans_Ct:</u></b> Recuento total de transacciones (últimos 12 meses)
# * <b><u>Total_Ct_Chng_Q4_Q1:</u></b> Cambio en el recuento de transacciones (Q4 sobre Q1)
# * <b><u>Avg_Utilization_Ratio:</u></b> Índice de utilización promedio de la tarjeta

# %% [markdown]
# <a id="2"></a>
# <h1 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Exploratory Data Analysis (EDA)</h1>

# %% [markdown]
# <a id="2-1"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Missing Data</h3>

# %%
#Veamos que campos tenemos con null
print('Nulls')
print('----------------------------')
print(df.isnull().sum())
# Out:
# Nulls
# ----------------------------
# CLIENTNUM                   0
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# dtype: int64

# %% [markdown]
# *Como se puede observar, el conjunto de datos no presenta ningún valor nulo en sus registros.*

# %%
# Controlemos no tener ID de Clientes duplicados
duplicates = df['CLIENTNUM'].duplicated()
print("Número de duplicados en 'CLIENTNUM':", duplicates.sum())
# Out:
# Número de duplicados en 'CLIENTNUM': 0

# %% [markdown]
# *La variable CLIENTNUM nos muestra una unicidad completa, mostrandonos sin repetición a los clientes del banco en la muestra.*

# %%
#Examinemos algunos datos generales de los campos numéricos.
print(df.describe())
# Out:
#          CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count     10127.00      10127.00         10127.00        10127.00
# mean  739177606.33         46.33             2.35           35.93
# std    36903783.45          8.02             1.30            7.99
# min   708082083.00         26.00             0.00           13.00
# 25%   713036770.50         41.00             1.00           31.00
# 50%   717926358.00         46.00             2.00           36.00
# 75%   773143533.00         52.00             3.00           40.00
# max   828343083.00         73.00             5.00           56.00
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count                  10127.00                10127.00
# mean                       3.81                    2.34
# std                        1.55                    1.01
# min                        1.00                    0.00
# 25%                        3.00                    2.00
# ...

# %% [markdown]
# *El conjunto de datos no presenta valores nulos, y los datos con valores de cero son pertinentes e informativos, por lo que no es necesario realizar correcciones en estos datos. Además, la edad de los clientes se encuentra dentro de un rango válido.*

# %%
# Veamos los tipos de datos
df.dtypes
# Out:
# CLIENTNUM                     int64
# Attrition_Flag               object
# Customer_Age                  int64
# Gender                       object
# Dependent_count               int64
# Education_Level              object
# Marital_Status               object
# Income_Category              object
# Card_Category                object
# Months_on_book                int64
# Total_Relationship_Count      int64
# Months_Inactive_12_mon        int64
# Contacts_Count_12_mon         int64
# Credit_Limit                float64
# Total_Revolving_Bal           int64
# Avg_Open_To_Buy             float64
# Total_Amt_Chng_Q4_Q1        float64
# Total_Trans_Amt               int64
# Total_Trans_Ct                int64
# Total_Ct_Chng_Q4_Q1         float64
# Avg_Utilization_Ratio       float64
# dtype: object

# %% [markdown]
# *Los tipos de datos son acordes a los valores que se manejan en cada columna.*

# %% [markdown]
# <h5 style="text-align:left;text-decoration:underline;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;">Resumen del Dataset:</h5>
#
# Nuestro conjunto de datos abarca una variedad de variables que capturan información demográfica, de productos y comportamental de nuestros clientes. Desde el número único de cliente hasta detalles sobre tarjetas de crédito, ingresos y transacciones, cada columna nos brinda una perspectiva única.
# Esta muestra consta con 10127 clientes distintos y 21 variables.

# %% [markdown]
# <a id="2-2"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Análisis de Variables</h3>

# %%
# Veamos la distribución de la variable Attrition_Flag que será nuestra variable target
plt.figure(figsize=(12, 6))

cantidad = len(df['Attrition_Flag'])

sns.countplot(data = df,
              x = "Attrition_Flag")
plt.xlabel('Permanencia del cliente')
plt.ylabel('Cantidad de clientes')
plt.title('Distribución de la variable Attrition_Flag')
ax = plt.gca()
for p in ax.patches:
    x_text = p.get_x() + p.get_width() / 2.0  # Calcula la posición x del texto
    y_text = p.get_height()  # Toma la altura de la columna
    ax.text(x_text, y_text, f'{str(round(int(y_text)/cantidad,2) * 100)}%', # Indica posición x e y, y texto a mostrar 
            ha = 'center', # Alineación horizontal 
            va = 'bottom',  # Alineación vertical
            fontsize = 10, color = 'black', fontweight = 'bold')
plt.show()

# %% [markdown]
# *En esta muestra de datos que nos encontramos analizando, tenemos un 84% de clientes retenidos y un 16% de clientes perdidos.*

# %%
# Calcular la distribución de las categorías de Gender
gender_counts = df['Gender'].value_counts()

# Crear el gráfico de pastel
plt.figure(figsize=(8, 8))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140, colors=['lightcoral', 'lightgreen'])
plt.title("Distribución de Gender")
plt.axis('equal')  # Proporciona un círculo perfecto

plt.show()

# %% [markdown]
# *La distribución de género de los clientes del banco es prácticamente equitativa en ambos casos, lo que sugiere que esta variable no parece tener un impacto significativo en la retención de clientes.*

# %%
#Ahora la distribución de la edad
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x="Customer_Age", kde=True, color="skyblue")
plt.title("Distribución de la Edad de los Clientes")
plt.xlabel("Edad del Cliente")
plt.ylabel("Número de Clientes")

plt.show()

# %% [markdown]
# *Es evidente que la distribución de edades de los clientes en nuestro conjunto de datos sigue una distribución bastante normal, teniendo pocos clientes en los extremos, jóvenes y de edad avanzada. Veamos como es la distribución de la edad en comparación con los clientes retenidos y aquellos que no.*

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Attrition_Flag', y='Customer_Age', data=df)
plt.title("Distribución de Edades por Estado de Permanencia del Cliente")
plt.xlabel("Permanencia del Cliente")
plt.ylabel("Edad del Cliente")
plt.show()

# %% [markdown]
# *La distribución de la edad de los clientes del banco es uniforme tanto para los clientes que permanecen, como los que ya se fueron. Lo que nos lleva a especular que la edad no tiene un impacto predictivo para la retención de los clientes.*

# %%
# Calcular la distribución de las categorías de Card_Category
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x="Card_Category", color="#fce29a")
ax = plt.gca()
for p in ax.patches:
    x_text = p.get_x() + p.get_width() / 2.0  # Calcula la posición x del texto
    y_text = p.get_height()  # Toma la altura de la columna
    ax.text(x_text, y_text, f'{str(round(int(y_text)/cantidad,2) * 100)}%', # Indica posición x e y, y texto a mostrar 
            ha = 'center', # Alineación horizontal 
            va = 'bottom',  # Alineación vertical
            fontsize = 10, color = 'black', fontweight = 'bold')
plt.title("Distribución de Card_Category")
plt.xlabel("Categorias de Tarjetas")
plt.ylabel("Número de Clientes")

plt.show()

# %% [markdown]
# *El 93% de los clientes, es decir, prácticamente la totalidad, utiliza un paquete básico de tarjetas. Ahora, examinemos la relación entre este hecho y la retención de los clientes.*

# %%
#Veamos los tipos de tarjetas y su distribución por permanencia
custom_palette = {"Existing Customer": "#DC143C", "Attrited Customer": "#FF7F50"}

plt.figure(figsize = (12, 6))
sns.countplot(x = df['Card_Category'], hue = df['Attrition_Flag'], palette=custom_palette)
ax = plt.gca()
for p in ax.patches:
    x_text = p.get_x() + p.get_width() / 2.0  # Calcula la posición x del texto
    y_text = p.get_height()  # Toma la altura de la columna
    ax.text(x_text, y_text, f'{str(round(int(y_text)/cantidad,2) * 100)}%', # Indica posición x e y, y texto a mostrar 
            ha = 'center', # Alineación horizontal 
            va = 'bottom',  # Alineación vertical
            fontsize = 10, color = 'black', fontweight = 'bold')
plt.title("Distribución de la categoría de Tarjeta por Permanencia de Clientes")
plt.xlabel("Categoría de Tarjeta")
plt.ylabel("Número de Clientes")
plt.show()

# %% [markdown]
# *Como era de esperar, la mayoría de los clientes opta por el tipo de tarjeta Blue. Aunque los grupos restantes son pequeños en cantidad, ser cliente con uno de estos paquetes podría ser un indicativo de que el cliente tendrá alta probabilidad de permanecer mas tiempo en el banco.*

# %%
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x="Dependent_count", color="#199260")
ax = plt.gca()
for p in ax.patches:
    x_text = p.get_x() + p.get_width() / 2.0  # Calcula la posición x del texto
    y_text = p.get_height()  # Toma la altura de la columna
    ax.text(x_text, y_text, f'{str(round(int(y_text)/cantidad,2) * 100)}%', # Indica posición x e y, y texto a mostrar 
            ha = 'center', # Alineación horizontal 
            va = 'bottom',  # Alineación vertical
            fontsize = 10, color = 'black', fontweight = 'bold')
plt.title("Distribución de Dependent_count")
plt.xlabel("Cantidad de Hijos")
plt.ylabel("Número de Clientes")

plt.show()

# %% [markdown]
# *La distribución de los dependientes (hijos) se distribuye de forma bastante normal. Veamos en comparación con los clientes retenidos y aquellos que dejaron de serlo para ver si hay algún patrón.*

# %%
#Veamos la cantidad de hijos y su distribución por permanencia
custom_palette = {"Existing Customer": "#ff0000", "Attrited Customer": "#ffc100"}

plt.figure(figsize = (12, 6))
sns.countplot(x = df['Dependent_count'], hue = df['Attrition_Flag'], palette=custom_palette)
ax = plt.gca()
for p in ax.patches:
    x_text = p.get_x() + p.get_width() / 2.0  # Calcula la posición x del texto
    y_text = p.get_height()  # Toma la altura de la columna
    ax.text(x_text, y_text, f'{str(round(int(y_text)/cantidad,2) * 100)}%', # Indica posición x e y, y texto a mostrar 
            ha = 'center', # Alineación horizontal 
            va = 'bottom',  # Alineación vertical
            fontsize = 10, color = 'black', fontweight = 'bold')
plt.title("Distribución de la cantidad de hijos por Permanencia de Clientes")
plt.xlabel("Cantidad de Hijos")
plt.ylabel("Número de Clientes")
plt.show()

# %% [markdown]
# *Esta distribución en comparativa no nos arroja un valor que se pueda aprovechar para nuestra predicción.*

# %%
# Calcular la distribución de las categorías de Education_Level
# Definimos un orden para el nivel de educación
education_order = ['Unknown','Uneducated','College','High School','Graduate','Post-Graduate','Doctorate']

# Convierte la columna 'Education_Level' en un tipo categórico con el orden deseado
df['Education_Level'] = pd.Categorical(df['Education_Level'], categories=education_order, ordered=True)

plt.figure(figsize=(8, 6))
sns.countplot(data=df, x="Education_Level", color="#78d278")
ax = plt.gca()
for p in ax.patches:
    x_text = p.get_x() + p.get_width() / 2.0  # Calcula la posición x del texto
    y_text = p.get_height()  # Toma la altura de la columna
    ax.text(x_text, y_text, f'{str(round(int(y_text)/cantidad,2) * 100)}%', # Indica posición x e y, y texto a mostrar 
            ha = 'center', # Alineación horizontal 
            va = 'bottom',  # Alineación vertical
            fontsize = 10, color = 'black', fontweight = 'bold')
plt.title("Distribución de Education_Level")
plt.xlabel("Nivel de Estudio")
plt.ylabel("Número de Clientes")

plt.show()

# %% [markdown]
# *Podemos afirmar que el 70% de los clientes posee educación, mientras que el 30% restante no la posee. De este 30%, un 15% se clasifica como desconocido. Veamos si el nivel de estudio puede ofrecernos un valor predictivo mayor a las variables anteriores.*

# %%
#Veamos los niveles de estudios de los clientes y su distribución por permanencia
custom_palette = {"Existing Customer": "#eeaf61", "Attrited Customer": "#6a0d83"}

plt.figure(figsize = (12, 6))
sns.countplot(x = df['Education_Level'], hue = df['Attrition_Flag'], palette=custom_palette)
ax = plt.gca()
for p in ax.patches:
    x_text = p.get_x() + p.get_width() / 2.0  # Calcula la posición x del texto
    y_text = p.get_height()  # Toma la altura de la columna
    ax.text(x_text, y_text, f'{str(round(int(y_text)/cantidad,2) * 100)}%', # Indica posición x e y, y texto a mostrar 
            ha = 'center', # Alineación horizontal 
            va = 'bottom',  # Alineación vertical
            fontsize = 10, color = 'black', fontweight = 'bold')
plt.title("Distribución del Nivel de Estudios por Permanencia de Clientes")
plt.xlabel("Nivel de Estudios")
plt.ylabel("Número de Clientes")
plt.show()

# %% [markdown]
# *La comparativa nos demuestra que el nivel de educación no posee un poder predictivo relevante.*

# %%
# Calcular la distribución de las categorías de Marital_Status
education_counts = df['Marital_Status'].value_counts()

# Crear el gráfico de pastel
plt.figure(figsize=(6, 6))
plt.pie(education_counts, labels=education_counts.index, autopct='%1.1f%%', startangle=140, colors=['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightblue', 'lightpink', 'lightyellow'])
plt.title("Distribución de Marital_Status")
plt.axis('equal')  # Proporciona un círculo perfecto

plt.show()

# %% [markdown]
# *Casi la mitad de los clientes del banco están casados, mientras que la otra mitad son clientes solteros, en una proporción sorprendentemente equitativa. Solo aproximadamente el 7% de los clientes están divorciados.*

# %%
#Veamos la distribución del estado civil y su distribución por permanencia
custom_palette = {"Existing Customer": "#0affa0", "Attrited Customer": "#87ffd0"}

plt.figure(figsize = (12, 6))
sns.countplot(x = df['Marital_Status'], hue = df['Attrition_Flag'], palette=custom_palette)
ax = plt.gca()
for p in ax.patches:
    x_text = p.get_x() + p.get_width() / 2.0  # Calcula la posición x del texto
    y_text = p.get_height()  # Toma la altura de la columna
    ax.text(x_text, y_text, f'{str(round(int(y_text)/cantidad,2) * 100)}%', # Indica posición x e y, y texto a mostrar 
            ha = 'center', # Alineación horizontal 
            va = 'bottom',  # Alineación vertical
            fontsize = 10, color = 'black', fontweight = 'bold')
plt.title("Distribución del Estado Civil por Permanencia de Clientes")
plt.xlabel("Estado Civil")
plt.ylabel("Número de Clientes")
plt.show()

# %% [markdown]
# *El estado civil de los clientes del banco no muestra, nuevamente un valor significativo para el ánalisis de la predicción.*

# %%
# Calcular la distribución de las categorías de Income_Category
# Definimos un orden para los ingresos
income_order = ['Less than $40K','$40K - $60K','$60K - $80K','$80K - $120K','$120K +','Unknown']

# Convierte la columna 'Income_Category' en un tipo categórico con el orden deseado
df['Income_Category'] = pd.Categorical(df['Income_Category'], categories=income_order, ordered=True)

plt.figure(figsize=(8, 6))
sns.countplot(data=df, x="Income_Category", color="#00ff0d")
ax = plt.gca()
for p in ax.patches:
    x_text = p.get_x() + p.get_width() / 2.0  # Calcula la posición x del texto
    y_text = p.get_height()  # Toma la altura de la columna
    ax.text(x_text, y_text, f'{str(round(int(y_text)/cantidad,2) * 100)}%', # Indica posición x e y, y texto a mostrar 
            ha = 'center', # Alineación horizontal 
            va = 'bottom',  # Alineación vertical
            fontsize = 10, color = 'black', fontweight = 'bold')
plt.title("Distribución de Income_Category")
plt.xlabel("Nivel de Ingresos")
plt.ylabel("Número de Clientes")

plt.show()

# %% [markdown]
# *Contamos con un 67% de los clientes del banco que tienen ingresos inferiores a los $80,000, y un 82% con ingresos por debajo de los $120,000, aunque también se registra un 11% con ingresos desconocidos.*

# %%
#Veamos la distribución del ingreso y su comparativa por permanencia
custom_palette = {"Existing Customer": "#5f2988", "Attrited Customer": "#9f7fb8"}

plt.figure(figsize = (12, 6))
sns.countplot(x = df['Income_Category'], hue = df['Attrition_Flag'], palette=custom_palette)
ax = plt.gca()
for p in ax.patches:
    x_text = p.get_x() + p.get_width() / 2.0  # Calcula la posición x del texto
    y_text = p.get_height()  # Toma la altura de la columna
    ax.text(x_text, y_text, f'{str(round(int(y_text)/cantidad,2) * 100)}%', # Indica posición x e y, y texto a mostrar 
            ha = 'center', # Alineación horizontal 
            va = 'bottom',  # Alineación vertical
            fontsize = 10, color = 'black', fontweight = 'bold')
plt.title("Distribución de los Ingresos por Permanencia de Clientes")
plt.xlabel("Ingresos")
plt.ylabel("Número de Clientes")
plt.show()

# %% [markdown]
# *La permanencia de los clientes en base a sus ingreso parece tener un valor predictivo bajo.*

# %%
# Crea el boxplot
plt.figure(figsize=(12, 4))
sns.boxplot(x=df['Months_on_book'], color="#a5a5a5")
plt.title("Boxplot de Months_on_book")
plt.xlabel("Meses en los libros del banco")

plt.show()

# %% [markdown]
# *La mayoría de los clientes tienen una permanencia en los libros del banco que oscila entre más de 30 meses y hasta 40 meses.*

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Attrition_Flag', y='Months_on_book', data=df)
plt.title("Distribución de la cantidad de meses por Estado de Permanencia del Cliente")
plt.xlabel("Permanencia del Cliente")
plt.ylabel("Meses en el banco del Cliente")
plt.show()

# %% [markdown]
# *En esta variable nos demuestra lo que se espera, los clientes retenidos optan por permanecer mas tiempo en el banco y por el contrario los que dejan de ser clientes permanecen menor cantidad de tiempo.*

# %%
# Calcular la distribución de Total_Relationship_Count
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x="Total_Relationship_Count", color="#66b2b2")
ax = plt.gca()
for p in ax.patches:
    x_text = p.get_x() + p.get_width() / 2.0  # Calcula la posición x del texto
    y_text = p.get_height()  # Toma la altura de la columna
    ax.text(x_text, y_text, f'{str(round(int(y_text)/cantidad,2) * 100)}%', # Indica posición x e y, y texto a mostrar 
            ha = 'center', # Alineación horizontal 
            va = 'bottom',  # Alineación vertical
            fontsize = 10, color = 'black', fontweight = 'bold')
plt.title("Distribución de Total_Relationship_Count")
plt.xlabel("Cantidad de Productos")
plt.ylabel("Número de Clientes")

plt.show()

# %% [markdown]
# *El 79% de los clientes tiene tres o más productos del banco.*

# %%
#Veamos la distribución de la cantidad de productos y su distribución por permanencia
custom_palette = {"Existing Customer": "#ff0000", "Attrited Customer": "#fdff00"}

plt.figure(figsize = (12, 6))
sns.countplot(x = df['Total_Relationship_Count'], hue = df['Attrition_Flag'], palette=custom_palette)
ax = plt.gca()
for p in ax.patches:
    x_text = p.get_x() + p.get_width() / 2.0  # Calcula la posición x del texto
    y_text = p.get_height()  # Toma la altura de la columna
    ax.text(x_text, y_text, f'{str(round(int(y_text)/cantidad,2) * 100)}%', # Indica posición x e y, y texto a mostrar 
            ha = 'center', # Alineación horizontal 
            va = 'bottom',  # Alineación vertical
            fontsize = 10, color = 'black', fontweight = 'bold')
plt.title("Distribución de la Cantidad de Productos por Permanencia de Clientes")
plt.xlabel("Cantidad de Productos")
plt.ylabel("Número de Clientes")
plt.show()

# %% [markdown]
# *La cantidad de productos contratados por los clientes no muestra un valor predictivo importante.*

# %%
# Crea el boxplot
plt.figure(figsize=(12, 4))
sns.boxplot(x=df['Months_Inactive_12_mon'], color="#e0ac69")
plt.title("Boxplot de Months_Inactive_12_mon")
plt.xlabel("Meses Inactivos en los últimos 12 meses")

plt.show()

# %% [markdown]
# *La mayoría de los clientes que permanecen inactivos lo hacen durante un período de 2 a 3 meses.*

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Attrition_Flag', y='Months_Inactive_12_mon', data=df)
plt.title("Distribución de la cantidad de meses inactivos por Estado de Permanencia del Cliente")
plt.xlabel("Permanencia del Cliente")
plt.ylabel("Meses Inactivos en el Banco")
plt.show()

# %% [markdown]
# *Los clientes retenidos tienden a tener tiempos de inactividad más bajos en comparación con los clientes perdidos, cuyos tiempos de inactividad tienden a ser más dispersos.*

# %%
#Ahora la distribución del Credit_Limit
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x="Credit_Limit", kde=True, color="#05ffa1")
plt.title("Distribución del límite de crédito de los Clientes")
plt.xlabel("Límite de crédito")
plt.ylabel("Número de Clientes")

plt.show()

# %% [markdown]
# *Esta variable sigue una distribución asimétrica positiva, la cola derecha más larga sugiere que hay un grupo de clientes con límites de crédito considerablemente altos. Esto podría deberse a factores como ingresos elevados, historial crediticio sólido o relaciones más largas con el banco.*

# %%
#Ahora la distribución del Total_Trans_Amt
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x="Total_Trans_Amt", kde=True, color="#b967ff")
plt.title("Distribución del monto total de transacciones")
plt.xlabel("Monto de las transacciones")
plt.ylabel("Número de Clientes")

plt.show()

# %% [markdown]
# *En los montos de las transacciones, observamos una distribución multimodal, ya que parece haber cuatro grupos significativos, cada uno de los cuales sigue una distribución normal.
# Cada pico en el gráfico podría representar un grupo de clientes con un comportamiento específico en términos de montos de transacciones. Por ejemplo, podríamos tener grupos de clientes que realizan transacciones pequeñas y frecuentes, así como grupos que realizan transacciones grandes y menos frecuentes.*

# %%
#Ahora la distribución del Total_Trans_Ct
plt.figure(figsize=(10, 6))
sns.histplot(data=df, x="Total_Trans_Ct", kde=True, color="#ff0044")
plt.title("Distribución del Recuento Total de transacciones")
plt.xlabel("Recuento Total de las transacciones")
plt.ylabel("Número de Clientes")

plt.show()

# %% [markdown]
# *El recuento total de transacciones muestra dos picos importantes, dichos picos podrían indicar dos grupos diferentes de clientes con diferentes comportamientos de transacción.*

# %%
# Boxplot
plt.figure()
sns.boxplot(data = df,
            x = 'Total_Trans_Ct',
            y = 'Attrition_Flag', 
            showfliers = False)
plt.title('Relación entre el recuento Total de Transacciones y la retención de clientes')
# Out:
# Text(0.5, 1.0, 'Relación entre el recuento Total de Transacciones y la retención de clientes')

# %% [markdown]
# *Al analizar el total del recuento de las transacciones contra los clientes retenidos vemos notoriamente que estos manejan una cantidad de transacciones muy superior que aquellos clientes que dejan de serlo.*

# %% [markdown]
# <a id="3"></a>
# <h1 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Variable Target</h1>

# %% [markdown]
# *Nuestra variable objetivo indica un valor de 1 si el cliente todavía mantiene su relación con el banco y un valor de 0 si ya no es cliente.*

# %%
Attrition_Flag_map = {
    'Existing Customer' : 1,
    'Attrited Customer' : 0
}

df.loc[:, 'Attrition_Flag'] = df['Attrition_Flag'].map(Attrition_Flag_map)
df['Attrition_Flag'] = df['Attrition_Flag'].astype(int)

# %% [markdown]
# *El objetivo de este análisis es identificar los patrones más efectivos para distinguir entre los clientes que permanecen y los que dejan de serlo.*
#
# *La variable objetivo es **Attrition_Flag** que es de naturaleza binaria. En consecuencia, el modelo a desarrollar será de tipo **Aprendizaje Supervisado: Clasificación**.*
#
# *A continuación, se presentarán algunas estadísticas con el propósito de comprender el comportamiento, el formato y la distribución de esta variable.*

# %%
# Veamos nuestra variable target gráficamente
plt.figure(figsize=(12, 6))

cantidad = len(df['Attrition_Flag'])

sns.countplot(data = df,
              x = "Attrition_Flag")
plt.xlabel('Permanencia del cliente')
plt.ylabel('Cantidad de clientes')
plt.title('Distribución de la variable Attrition_Flag')
ax = plt.gca()
for p in ax.patches:
    x_text = p.get_x() + p.get_width() / 2.0  # Calcula la posición x del texto
    y_text = p.get_height()  # Toma la altura de la columna
    ax.text(x_text, y_text, f'{str(round(int(y_text)/cantidad,2) * 100)}%', # Indica posición x e y, y texto a mostrar 
            ha = 'center', # Alineación horizontal 
            va = 'bottom',  # Alineación vertical
            fontsize = 10, color = 'black', fontweight = 'bold')
plt.show()

# %% [markdown]
# <a id="3-1"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Information Value</h3>

# %% [markdown]
# *Creemos una función que nos permita calcular el information value de cualquier variable que querramos de nuestra dataset. Esta recibira nuestro df, la variable de la cual calcularemos el IV y nuestra variable target.*

# %%
def calculate_iv(df, variable, target):
    # Calcula el número total de eventos y no eventos
    total_events = df[target].sum()
    total_non_events = df[target].count() - total_events

    # Crea una tabla de contingencia entre la variable y el target
    iv_table = pd.crosstab(df[variable], df[target])

    epsilon = 0.1

    # Calcula el porcentaje de eventos y no eventos en cada categoría de la variable,
    # agregando 0.5 para evitar divisiones por cero
    iv_table['event_percentage'] = (iv_table[1] + epsilon) / (total_events + epsilon)
    iv_table['non_event_percentage'] = (iv_table[0] + epsilon) / (total_non_events + epsilon)

    # Calcula la diferencia entre los porcentajes de eventos y no eventos
    iv_table['percentage_diff'] = iv_table['event_percentage'] - iv_table['non_event_percentage']

    # Calcula el logaritmo natural de la razón, asegurándose de manejar valores de 0
    iv_table['ln_ratio'] = np.log(iv_table['event_percentage'] / iv_table['non_event_percentage'])

    # Calcula el IV para cada categoría y suma todos los IV para obtener el IV total
    iv_table['IV'] = iv_table['percentage_diff'] * iv_table['ln_ratio']
    iv = iv_table['IV'].sum()

    return round(iv,2)

# %% [markdown]
# *Ahora pasemos todas nuestras variables por nuestra función y veamos los distintos IV de cada uno de ellas.*

# %%
# Crear un diccionario para almacenar los resultados
iv_results = {'Variable': [], 'IV': []}

# Lista de variables a analizar
variables_a_analizar = ['Customer_Age', 'Gender',
       'Dependent_count', 'Education_Level', 'Marital_Status',
       'Income_Category', 'Card_Category', 'Months_on_book',
       'Total_Relationship_Count', 'Months_Inactive_12_mon',
       'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
       'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
       'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio']  # Agrega aquí las variables que desees analizar

# Loop para calcular IV para cada variable
for variable in variables_a_analizar:
    iv_value = calculate_iv(df, variable, 'Attrition_Flag')  # Utiliza la función calculate_iv que definimos anteriormente
    iv_results['Variable'].append(variable)
    iv_results['IV'].append(iv_value)

# Crear el DataFrame a partir del diccionario
iv_results_df = pd.DataFrame(iv_results)

# Ordena el DataFrame por la columna "IV" en orden descendente (mayor IV primero)
iv_results_df = iv_results_df.sort_values(by='IV', ascending=False)

# Mostrar los resultados
iv_results_df
# Out:
#                     Variable   IV
# 15           Total_Trans_Amt 4.03
# 13           Avg_Open_To_Buy 3.63
# 11              Credit_Limit 3.23
# 12       Total_Revolving_Bal 2.21
# 17       Total_Ct_Chng_Q4_Q1 2.17
# 16            Total_Trans_Ct 2.07
# 18     Avg_Utilization_Ratio 1.60
# 14      Total_Amt_Chng_Q4_Q1 1.23
# 10     Contacts_Count_12_mon 0.55
# 9     Months_Inactive_12_mon 0.37
# 8   Total_Relationship_Count 0.19
# 0               Customer_Age 0.05
# 7             Months_on_book 0.04
# 1                     Gender 0.01
# 5            Income_Category 0.01
# 3            Education_Level 0.01
# 2            Dependent_count 0.01
# 6              Card_Category 0.00
# 4             Marital_Status 0.00

# %% [markdown]
# *Hemos corroborado lo que anteriormente se detecto en los gráficos, las variables Gender, Income_Category, Education_Level, Dependent_count, Card_Category, Marital_Status no tiene valor predictivo para nuestra variable target. El resto de las variables demuestra un poder predictivo alto y analizaremos con mayor atención aquellas con un valor muy alto.*

# %% [markdown]
# <a id="3-2"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Árbol de Decisiones</h3>

# %% [markdown]
# *Creemos nuevos predictores basandonos en algunas de las variables que mayor IV dieron. Estas nuevas variables binarias se crean en base a los gráficos anteriores donde utilizaremos como criterio un valor que se corresponda con el 60% o 75% de los datos para determinar un punto de inflexión.*

# %%
# Genero predictores a usar
df['Es_Cliente'] = df['Attrition_Flag'] == 1
df['Es_Adulto_Joven'] = df['Customer_Age'] < 40
df['Tiene_muchos_productos'] = df['Total_Relationship_Count'] > 3
df['Usa_Mucho_tarjeta'] = df['Avg_Utilization_Ratio'] > 0.4
df['Tiene_Cartera_Credito_Alto'] = df['Avg_Open_To_Buy'] > 9900
df['Mueve_Mucho_Dinero'] = df['Total_Trans_Amt'] > 4000
df['Posee_Credito_Alto'] = df['Credit_Limit'] > 11000
df['Saldo_Rotativo_Alto'] = df['Total_Revolving_Bal'] > 1500

# Los enlisto: 
lista_predictores = ['Es_Adulto_Joven','Tiene_muchos_productos','Usa_Mucho_tarjeta','Mueve_Mucho_Dinero','Posee_Credito_Alto','Tiene_Cartera_Credito_Alto','Saldo_Rotativo_Alto']

# Los transformo en matriz: 
X = df[lista_predictores].values

# %%
# Genero vector de target
y = df['Es_Cliente'].values

# %%
# Genero modelo: árbol de decisión 
clf = DecisionTreeClassifier(random_state = 1234, # Semilla aleatoria
                             criterion = 'gini', # Funcion para medir calidad de la división
                             splitter = 'best', # Estrategia para elegir la división de cada nodo
                             max_depth = 4, # Profundidad máxima del árbol
                             min_samples_leaf = 20 # Mínima cantidad de registros por nodo final
                            )
clf.feature_names = lista_predictores
model = clf.fit(X, y)

# %%
plt.figure(figsize=(24, 16))
plot_tree(clf, 
          filled = True, 
          rounded = True, 
          class_names = ['No es Cliente','Es Cliente'], 
          feature_names = lista_predictores, 
          impurity = False,
          proportion = True,
          node_ids = True)
# Out:
# [Text(0.5446428571428571, 0.9, 'node #0\nMueve_Mucho_Dinero <= 0.5\nsamples = 100.0%\nvalue = [0.161, 0.839]\nclass = Es Cliente'),
#  Text(0.2857142857142857, 0.7, 'node #1\nTiene_muchos_productos <= 0.5\nsamples = 52.2%\nvalue = [0.249, 0.751]\nclass = Es Cliente'),
#  Text(0.14285714285714285, 0.5, 'node #2\nSaldo_Rotativo_Alto <= 0.5\nsamples = 18.5%\nvalue = [0.422, 0.578]\nclass = Es Cliente'),
#  Text(0.07142857142857142, 0.3, 'node #3\nUsa_Mucho_tarjeta <= 0.5\nsamples = 12.0%\nvalue = [0.51, 0.49]\nclass = No es Cliente'),
#  Text(0.03571428571428571, 0.1, 'node #4\nsamples = 10.6%\nvalue = [0.542, 0.458]\nclass = No es Cliente'),
#  Text(0.10714285714285714, 0.1, 'node #5\nsamples = 1.3%\nvalue = [0.259, 0.741]\nclass = Es Cliente'),
#  Text(0.21428571428571427, 0.3, 'node #6\nUsa_Mucho_tarjeta <= 0.5\nsamples = 6.6%\nvalue = [0.262, 0.738]\nclass = Es Cliente'),
#  Text(0.17857142857142858, 0.1, 'node #7\nsamples = 3.2%\nvalue = [0.19, 0.81]\nclass = Es Cliente'),
# ...

# %%
# Genero predicciones  
df['Predict_Arbol_Clase'] = clf.predict(df[lista_predictores])
df['Predict_Arbol_Nodo'] = clf.apply(df[lista_predictores])

# %%
df['Predict_Arbol_Clase'].value_counts()
# Out:
# Predict_Arbol_Clase
# True     9049
# False    1078
# Name: count, dtype: int64

# %%
df['Predict_Arbol_Nodo'].value_counts()
# Out:
# Predict_Arbol_Nodo
# 19    1668
# 11    1432
# 4     1078
# 14     726
# 25     720
# 22     702
# 15     676
# 12     577
# 28     505
# 27     486
# 23     444
# 8      343
# 7      321
# 20     314
# 5      135
# Name: count, dtype: int64

# %%
# Groupby por prediccion de clase: 
resultados = df.groupby('Predict_Arbol_Clase').agg(
    Cant = ('Predict_Arbol_Clase', 'count'),              
    Cant_Cliente = ('Es_Cliente', 'sum'),            
    Tasa_EsCliente = ('Es_Cliente', 'mean')    
).reset_index()
resultados
# Out:
#    Predict_Arbol_Clase  Cant  Cant_Cliente  Tasa_EsCliente
# 0                False  1078           494            0.46
# 1                 True  9049          8006            0.88

# %% [markdown]
# *La predicción de nuestro árbol de decisiones tuvo una efectividad del 88%, lo que nos confirma que los predictores elegidos tiene valor predictivo muy alto.*

# %%
# Groupby por prediccion de nodo: 
resultados_nodo = df.groupby('Predict_Arbol_Nodo').agg(     
    Cant = ('Predict_Arbol_Nodo', 'count'),              
    Cant_Cliente = ('Es_Cliente', 'sum'),            
    Tasa_EsCliente = ('Es_Cliente', 'mean')    
).reset_index()
resultados_nodo.rename(columns={'Tasa_Cliente': 'Predict_Prob_Arbol'}, inplace=True)
resultados_nodo_ordenado = resultados_nodo.sort_values(by='Tasa_EsCliente', ascending=False)
resultados_nodo_ordenado
# Out:
#     Predict_Arbol_Nodo  Cant  Cant_Cliente  Tasa_EsCliente
# 12                  25   720           720            1.00
# 14                  28   505           499            0.99
# 13                  27   486           475            0.98
# 6                   14   726           691            0.95
# 8                   19  1668          1557            0.93
# 11                  23   444           408            0.92
# 5                   12   577           513            0.89
# 9                   20   314           279            0.89
# 7                   15   676           599            0.89
# 10                  22   702           592            0.84
# 2                    7   321           260            0.81
# 4                   11  1432          1083            0.76
# 1                    5   135           100            0.74
# 3                    8   343           230            0.67
# 0                    4  1078           494            0.46

# %%
# Groupby por prediccion de nodo: 
resultados_nodo = df.groupby('Predict_Arbol_Nodo').agg(     
    Cant = ('Predict_Arbol_Nodo', 'count'),              
    Cant_Cliente = ('Es_Cliente', 'sum'),            
    Tasa_EsCliente = ('Es_Cliente', 'mean')    
).reset_index()
resultados_nodo.rename(columns={'Tasa_EsCliente': 'Predict_Prob_Arbol'}, inplace=True)
resultados_nodo_ordenado = resultados_nodo.sort_values(by='Predict_Prob_Arbol', ascending=False)
resultados_nodo_ordenado
# Out:
#     Predict_Arbol_Nodo  Cant  Cant_Cliente  Predict_Prob_Arbol
# 12                  25   720           720                1.00
# 14                  28   505           499                0.99
# 13                  27   486           475                0.98
# 6                   14   726           691                0.95
# 8                   19  1668          1557                0.93
# 11                  23   444           408                0.92
# 5                   12   577           513                0.89
# 9                   20   314           279                0.89
# 7                   15   676           599                0.89
# 10                  22   702           592                0.84
# 2                    7   321           260                0.81
# 4                   11  1432          1083                0.76
# 1                    5   135           100                0.74
# 3                    8   343           230                0.67
# ...

# %%
# Genero la columna con la predicción 
df = df.merge(resultados_nodo[['Predict_Arbol_Nodo','Predict_Prob_Arbol']],
              left_on = 'Predict_Arbol_Nodo',
              right_on = 'Predict_Arbol_Nodo',
              how = 'left')
df.head()
# Out:
#    CLIENTNUM  Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383               1            45      M                3
# 1  818770008               1            49      F                5
# 2  713982108               1            51      M                3
# 3  769911858               1            40      F                4
# 4  709106358               1            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Es_Adulto_Joven  Tiene_muchos_productos  \
# 0              39  ...            False                    True
# ...

# %%
# Graficamente 
g1 = plt.figure()
sns.scatterplot(data = df,
                x = 'CLIENTNUM',
                y = 'Predict_Prob_Arbol',  
                alpha = 0.75,
                hue = 'Attrition_Flag')
# Out:
# <Axes: xlabel='CLIENTNUM', ylabel='Predict_Prob_Arbol'>

# %%
# Histogramas de predicción 
g1 = plt.figure()
sns.histplot(data = df,
             x = 'Predict_Prob_Arbol',  
             alpha = 0.5,
             hue = 'Attrition_Flag',
             stat = 'probability', 
             bins = 4)
# Out:
# <Axes: xlabel='Predict_Prob_Arbol', ylabel='Probability'>

# %%
# Barplot por nodo 
resultados_nodo['Tasa_NoCliente'] = (1 - resultados_nodo['Predict_Prob_Arbol'])
sns.barplot(data = resultados_nodo,
            x = 'Predict_Arbol_Nodo',
            y = 'Predict_Prob_Arbol', 
            label = 'Porcentaje EsCliente',
            color = '#48E074')
sns.barplot(data=resultados_nodo, 
            x = 'Predict_Arbol_Nodo', 
            y = 'Tasa_NoCliente', 
            bottom=resultados_nodo['Predict_Prob_Arbol'], 
            label = 'Porcentaje No Es Cliente',
            color = '#E04848')
# Out:
# <Axes: xlabel='Predict_Arbol_Nodo', ylabel='Tasa_NoCliente'>

# %% [markdown]
# *Exceptuando el nodo 4, el resto de los nodos del árbol de decisiones muestran un alto valor predictivo.*

# %% [markdown]
# <a id="4"></a>
# <h1 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Regresión Logística</h1>

# %% [markdown]
# *Antes de comenzar con la regresión generaremos nuevas variables para nuestro análisis, estas son, "Total_Trans_Amt_Group" que agrupará en 4 grupos distintos los datos de esta variable (basaremos los límites de esta según su gráfico), "Total_Trans_Amt_Group_Promedio" que contendra el promedio de cada grupo y "Cociente_Trans_Amt_Ct" que será el cociente entre el monto de las transacciones y la cantidad de estas.*

# %%
# Crear los límites de los grupos
bins = [0, 3000, 6000, 12000, float('inf')]

# Etiquetas para los grupos
labels = ['1', '2', '3', '4']

# Crear la nueva variable categórica basada en los grupos
df['Total_Trans_Amt_Group'] = pd.cut(df['Total_Trans_Amt'], bins=bins, labels=labels, right=False)

# Visualizar el resultado
print(df[['Total_Trans_Amt', 'Total_Trans_Amt_Group']])
# Out:
#        Total_Trans_Amt Total_Trans_Amt_Group
# 0                 1144                     1
# 1                 1291                     1
# 2                 1887                     1
# 3                 1171                     1
# 4                  816                     1
# ...                ...                   ...
# 10122            15476                     4
# 10123             8764                     3
# 10124            10291                     3
# 10125             8395                     3
# 10126            10294                     3
#
# [10127 rows x 2 columns]

# %%
# Contar el número de registros en cada categoría
conteo_categorias = df['Total_Trans_Amt_Group'].value_counts()

# Mostrar el resultado
print(conteo_categorias)
# Out:
# Total_Trans_Amt_Group
# 2    4782
# 1    3895
# 4     746
# 3     704
# Name: count, dtype: int64

# %%
# Calcular el promedio de la variable objetivo para cada grupo
grouped_avg = df.groupby('Total_Trans_Amt_Group')['Attrition_Flag'].mean().reset_index()

# Renombrar la columna del promedio
grouped_avg.rename(columns={'Attrition_Flag': 'Total_Trans_Amt_Group_Promedio'}, inplace=True)

# Fusionar el DataFrame original con el DataFrame de promedios
df = df.merge(grouped_avg, on='Total_Trans_Amt_Group', how='left')

grouped_avg.head()
# Out:
#   Total_Trans_Amt_Group  Total_Trans_Amt_Group_Promedio
# 0                     1                            0.67
# 1                     2                            0.98
# 2                     3                            0.68
# 3                     4                            1.00

# %%
# Calculo el cociente entre el monto de las transacciones y la cantidad de estas
df['Cociente_Trans_Amt_Ct'] = df['Total_Trans_Amt'] / df['Total_Trans_Ct']

# %% [markdown]
# *Usemos Label Encoder para las variables de nuestro Arból de Decisiones, y usaremos estas para nuestro primer modelo.*

# %%
Income_Category_map = {
    'Less than $40K' : 0,
    '$40K - $60K'    : 1,
    '$60K - $80K'    : 2,
    '$80K - $120K'   : 3,
    '$120K +'        : 4,
    'Unknown'        : 5
}


Card_Category_map = {
    'Blue'     : 0,
    'Silver'   : 1,
    'Gold'     : 2,
    'Platinum' : 3
}


Education_Level_map = {
    'Uneducated'    : 0,
    'High School'   : 1,
    'College'       : 2,
    'Graduate'      : 3,
    'Post-Graduate' : 4,
    'Doctorate'     : 5,
    'Unknown'       : 6
}


df.loc[:, 'Income_Category'] = df['Income_Category'].map(Income_Category_map)
df.loc[:, 'Card_Category'] = df['Card_Category'].map(Card_Category_map)
df.loc[:, 'Education_Level'] = df['Education_Level'].map(Education_Level_map)

lbe = LabelEncoder()

cat_cols = [x for x in df.columns if df[x].dtype == 'object']

for c in cat_cols:
    df.loc[:, c] = lbe.fit_transform(df.loc[:, c])

# %% [markdown]
# *Dividamos la muestra en train y test.*

# %%
df_train,df_test = train_test_split(df,
                                    test_size = 0.2, #Porcentaje de muestra test 
                                    random_state = 123) #Semilla

# %% [markdown]
# *Corroboramos que ambas muestran tienen la misma tasa de retención.*

# %%
# Check tasas similares 
print('Tasa Retención TRAIN:')
print(round(df_train['Attrition_Flag'].mean(),2))
print('Tasa Retención TEST:')
print(round(df_test['Attrition_Flag'].mean(),2))
# Out:
# Tasa Retención TRAIN:
# 0.84
# Tasa Retención TEST:
# 0.85

# %% [markdown]
# <a id="4-1"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Modelo 1</h3>

# %% [markdown]
# *Para este primer modelo utilizaremos la variable que generamos recién "Total_Trans_Amt_Group_Promedio", y las variables de nuestro árbol de decisiones.*

# %%
# Predictores: 
lista_predictores = ['Total_Trans_Amt_Group_Promedio','Tiene_muchos_productos', 'Es_Adulto_Joven','Usa_Mucho_tarjeta',
                     'Tiene_Cartera_Credito_Alto','Posee_Credito_Alto','Saldo_Rotativo_Alto']

X_train = df_train[lista_predictores].values
y_train = df_train['Attrition_Flag'].values
X_test = df_test[lista_predictores].values
y_test = df_test['Attrition_Flag'].values

# Entrenar el modelo en el conjunto de entrenamiento
clf_1 = LogisticRegression()
clf_1.fit(X_train, y_train)

# Evaluar el modelo en el conjunto de prueba
y_pred = clf_1.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Precisión del modelo en el conjunto de prueba: {:.2f}%".format(accuracy * 100))

# Obtener las probabilidades predichas en lugar de las etiquetas de clase
y_prob_full = clf_1.predict_proba(df[lista_predictores])[:, 1]

# Agregar las probabilidades al DataFrame original
df['Probabilidad_Retencion_1'] = y_prob_full

# Obtener las probabilidades predichas en lugar de las etiquetas de clase
y_prob = clf_1.predict_proba(X_test)[:, 1]

print("Ajustemos el umbral para analizar posibles mejores resultados:")
# Ajustar el umbral que por defecto el algoritmo toma en 0.5
umbral = 0.4
y_pred_adjusted = (y_prob >= umbral).astype(int)

# Evaluar el modelo con el umbral ajustado
accuracy_adjusted = accuracy_score(y_test, y_pred_adjusted)
print("Precisión del modelo con umbral en {:.2f}: {:.2f}%".format(umbral, accuracy_adjusted * 100))

umbral = 0.6
y_pred_adjusted = (y_prob >= umbral).astype(int)

# Evaluar el modelo con el umbral ajustado
accuracy_adjusted = accuracy_score(y_test, y_pred_adjusted)
print("Precisión del modelo con umbral en {:.2f}: {:.2f}%".format(umbral, accuracy_adjusted * 100))
# Out:
# Precisión del modelo en el conjunto de prueba: 86.48%
# Ajustemos el umbral para analizar posibles mejores resultados:
# Precisión del modelo con umbral en 0.40: 87.22%
# Precisión del modelo con umbral en 0.60: 86.18%

# %% [markdown]
# *Obtenemos una buena predicción en este modelo con las variables elegidas. Ajustando el umbral para intentar obtener una mejor predicción encontramos que bajandolo a 0.40 obtenemos una ligera mejora.*

# %% [markdown]
# <a id="4-1-1"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Modelo 1 - Matriz de Confusión</h3>

# %%
# Calcular la matriz de confusión para el conjunto de entrenamiento
confusion_train = confusion_matrix(y_train, clf_1.predict(X_train))

# Calcular la matriz de confusión para el conjunto de prueba
confusion_test = confusion_matrix(y_test, clf_1.predict(X_test))

# Imprimir las matrices de confusión
print("Matriz de Confusión para Datos de Entrenamiento:")
print(confusion_train)

print("Matriz de Confusión para Datos de Prueba:")
print(confusion_test)
# Out:
# Matriz de Confusión para Datos de Entrenamiento:
# [[ 343  973]
#  [ 171 6614]]
# Matriz de Confusión para Datos de Prueba:
# [[  81  230]
#  [  44 1671]]

# %%
# Grafico
# Primero defino la estructura de mis gráficos a mostras
fig, ax = plt.subplots(nrows = 1,
                      ncols = 2,
                      figsize = (10,5)) 

# Luego indico lo que voy a dibujar en el primer cuadrante
sns.heatmap(confusion_test, 
            annot=True, fmt='d', cmap='Greens', cbar=False, 
            ax=ax[0])
ax[0].set_title('Testeo')
ax[0].set_xlabel('Predicción')
ax[0].set_ylabel('Real')

# Luego indico lo que voy a dibujar en el segundo cuadrante
sns.heatmap(confusion_train, 
            annot=True, fmt='d', cmap='Blues', cbar=False, 
            ax=ax[1])
ax[1].set_title('Entrenamiento')
ax[1].set_xlabel('Predicción')
ax[1].set_ylabel('Real')

# Muestra
plt.show()

# %% [markdown]
# *En el conjunto de testeo:*
#
# *El modelo predijo correctamente 1671 instancias positivas (1) que eran realmente positivas.*
# *El modelo predijo correctamente 81 instancias negativas (0) que eran realmente negativas.*
# *Hubo 230 falsos positivos, lo que significa que el modelo predijo positivo cuando en realidad era negativo.*
# *Hubo 44 falsos negativos, lo que significa que el modelo predijo negativo cuando en realidad era positivo.*
#
# *En el conjunto de entrenamiento:*
#
# *El modelo predijo correctamente 6614 instancias positivas (1) que eran realmente positivas.*
# *El modelo predijo correctamente 343 instancias negativas (0) que eran realmente negativas.*
# *Hubo 973 falsos positivos, lo que significa que el modelo predijo positivo cuando en realidad era negativo.*
# *Hubo 171 falsos negativos, lo que significa que el modelo predijo negativo cuando en realidad era positivo.*

# %%
# Calculemos las metricas, para eso vamos a guardar el resultado de cada cuadrante para utilizarlos 

# Paso 1: capturo cada uno de los elementos de la matriz de confusión 
Total_TEST = sum(sum(confusion_test))
Total_TRAIN = sum(sum(confusion_train))
TP_TEST = confusion_test[1,1]
TP_TRAIN = confusion_train[1,1]
TN_TEST = confusion_test[0,0]
TN_TRAIN = confusion_train[0,0]
FP_TEST = confusion_test[0,1]
FP_TRAIN = confusion_train[0,1]
FN_TEST = confusion_test[1,0]
FN_TRAIN = confusion_train[1,0]

# Paso 2: Calculo métricas
Precision_TEST = TP_TEST / (TP_TEST + FP_TEST)
Precision_TRAIN = TP_TRAIN / (TP_TRAIN + FP_TRAIN)
Recall_TEST = TP_TEST / (TP_TEST + FN_TEST)
Recall_TRAIN = TP_TRAIN / (TP_TRAIN + FN_TRAIN)
Accuracy_TEST = (TP_TEST + TN_TEST) / Total_TEST
Accuracy_TRAIN = (TP_TRAIN + TN_TRAIN) / Total_TRAIN
Especificidad_TEST = TN_TEST / (TN_TEST + FP_TEST)
Especificidad_TRAIN = TN_TRAIN / (TN_TRAIN + FP_TRAIN)

# Paso 3: Presento todo en una misma tabla 
metricas = pd.DataFrame(columns=['Poblacion', 'Metrica','Valor'])

# Precision
nuevo_dato = {'Poblacion': 'TEST', 
              'Metrica': 'Precision',
              'Valor': Precision_TEST}
metricas.loc[len(metricas)] = nuevo_dato
nuevo_dato = {'Poblacion': 'TRAIN', 
              'Metrica': 'Precision',
              'Valor': Precision_TRAIN}
metricas.loc[len(metricas)] = nuevo_dato

# Recall
nuevo_dato = {'Poblacion': 'TEST', 
              'Metrica': 'Recall',
              'Valor': Recall_TEST}
metricas.loc[len(metricas)] = nuevo_dato
nuevo_dato = {'Poblacion': 'TRAIN', 
              'Metrica': 'Recall',
              'Valor': Recall_TRAIN}
metricas.loc[len(metricas)] = nuevo_dato

# Accurancy
nuevo_dato = {'Poblacion': 'TEST', 
              'Metrica': 'Accuracy',
              'Valor': Accuracy_TEST}
metricas.loc[len(metricas)] = nuevo_dato
nuevo_dato = {'Poblacion': 'TRAIN', 
              'Metrica': 'Accuracy',
              'Valor': Accuracy_TRAIN}
metricas.loc[len(metricas)] = nuevo_dato

# Especificidad
nuevo_dato = {'Poblacion': 'TEST', 
              'Metrica': 'Especificidad',
              'Valor': Especificidad_TEST}
metricas.loc[len(metricas)] = nuevo_dato
nuevo_dato = {'Poblacion': 'TRAIN', 
              'Metrica': 'Especificidad',
              'Valor': Especificidad_TRAIN}
metricas.loc[len(metricas)] = nuevo_dato

# Paso 4: Grafico 
plt.figure(figsize=(12, 5))
sns.barplot(data = metricas,
                x = 'Metrica',
                y = 'Valor',
                hue = 'Poblacion')
plt.xlabel('Tipo de Métrica')
plt.ylabel('Valor de la Métrica')
plt.title('Métricas - MODELO 1')
ax = plt.gca()
for p in ax.patches:
    x_text = p.get_x() + p.get_width() / 2.0  # Calcula la posición x del texto
    y_text = p.get_height()  # Toma la altura de la columna
    ax.text(x_text, y_text, f'{str(round(y_text,2) * 100)}%', # Indica posición x e y, y texto a mostrar 
            ha = 'center', # Alineación horizontal 
            va = 'bottom',  # Alineación vertical
            fontsize = 10, color = 'black', fontweight = 'bold')

plt.legend(loc='lower right')    
metricas_1 = plt.gcf()
plt.show()

# %% [markdown]
# *El modelo tiene un alto recall, lo que indica que es efectivo en identificar la mayoría de las instancias positivas. Sin embargo, hay un equilibrio con la precisión, que es ligeramente más baja, lo que indica que algunas de las predicciones positivas pueden ser falsas.
# La especificidad es bastante baja, lo que sugiere que el modelo tiene dificultades para identificar correctamente las instancias negativas.
# La exactitud es un indicador general y se encuentra en un nivel moderado del 86%.
# En resumen, el modelo tiene un buen rendimiento en la identificación de instancias positivas, pero podría mejorarse para reducir los falsos positivos y mejorar la especificidad. Esto podría lograrse mediante ajustes en el umbral de clasificación o mediante técnicas avanzadas de ajuste del modelo.*

# %% [markdown]
# <a id="4-1-2"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Validación del Modelo 1</h3>

# %% [markdown]
# <a id="4-1-3"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Métricas de Entrenamiento y Prueba - Modelo 1</h3>

# %%
# Predecir en el conjunto de entrenamiento
y_train_pred = clf_1.predict(X_train)

# Calcular la precisión en el conjunto de entrenamiento
accuracy_train = accuracy_score(y_train, y_train_pred)

# Predecir en el conjunto de prueba
y_test_pred = clf_1.predict(X_test)

# Calcular la precisión en el conjunto de prueba
accuracy_test = accuracy_score(y_test, y_test_pred)

# Imprimir las métricas de precisión
print("Precisión en el conjunto de entrenamiento: {:.2f}%".format(accuracy_train * 100))
print("Precisión en el conjunto de prueba: {:.2f}%".format(accuracy_test * 100))
# Out:
# Precisión en el conjunto de entrenamiento: 85.88%
# Precisión en el conjunto de prueba: 86.48%

# %% [markdown]
# <a id="4-1-4"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">K-fold Cross-Validation - Validación Cruzada - Modelo 1</h3>

# %%
X = df[lista_predictores].values
y = df['Attrition_Flag'].values

# Configurar K-fold Cross-Validation con 5 pliegues
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Realizar validación cruzada
cv_scores = cross_val_score(clf_1, X, y, cv=kfold, scoring='accuracy')

# Imprimir los resultados de la validación cruzada
print("Precisión de validación cruzada:")
for i, score in enumerate(cv_scores, start=1):
    print("Pliegue {}: {:.2f}%".format(i, score * 100))

print("\nPrecisión promedio: {:.2f}% (+/- {:.2f}%)".format(np.mean(cv_scores) * 100, np.std(cv_scores) * 100))
# Out:
# Precisión de validación cruzada:
# Pliegue 1: 85.34%
# Pliegue 2: 85.44%
# Pliegue 3: 86.42%
# Pliegue 4: 87.11%
# Pliegue 5: 85.68%
#
# Precisión promedio: 86.00% (+/- 0.67%)

# %% [markdown]
# *La precisión en cada pliegue es consistente y se mantiene en un rango estrecho entre el 85.34% y el 86.57%. La precisión promedio en la validación cruzada es del 85.99%, lo que sugiere que el modelo generaliza bien en diferentes subconjuntos de datos. Este valor promedio es útil para obtener una medida agregada del rendimiento del modelo. La consistencia en las métricas a lo largo de los pliegues sugiere que el modelo es robusto y no está sobreajustado a un conjunto de datos específico.*

# %% [markdown]
# <a id="4-1-5"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">AUC - Curva ROC - Modelo 1</h3>

# %%
# Calcular la curva ROC y el AUC para el conjunto de prueba (test)
y_pred_prob_test = clf_1.predict_proba(X_test)[:, 1]  # Probabilidades de pertenecer a la clase positiva
fpr_test, tpr_test, thresholds_test = roc_curve(y_test, y_pred_prob_test)
roc_auc_test = roc_auc_score(y_test, y_pred_prob_test)

# %%
# Calcular la curva ROC y el AUC para el conjunto de entrenamiento (train)
y_pred_prob_train = clf_1.predict_proba(X_train)[:, 1]  # Probabilidades de pertenecer a la clase positiva
fpr_train, tpr_train, thresholds_train = roc_curve(y_train, y_pred_prob_train)
roc_auc_train = roc_auc_score(y_train, y_pred_prob_train)

# %%
# Crear el gráfico con ambas curvas ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr_test, tpr_test, color='darkorange', lw=2, label='Test ROC curve (AUC = %0.2f)' % roc_auc_test)
plt.plot(fpr_train, tpr_train, color='green', lw=2, label='Train ROC curve (AUC = %0.2f)' % roc_auc_train)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# *Un AUC de 0.87 es bastante bueno y sugiere que el modelo tiene una capacidad sólida para distinguir entre las clases positivas y negativas. Cuanto más cercano esté el AUC a 1.0, mejor es la capacidad del modelo para clasificar correctamente las instancias de ambas clases. La consistencia entre el AUC del conjunto de prueba y el conjunto de entrenamiento sugiere que el modelo generaliza bien y no está sobreajustado al conjunto de entrenamiento.*

# %%
# Crear un DataFrame con las predicciones y los valores reales
comparison_df = pd.DataFrame({'Real': y_test, 'Predicción': y_pred})

# Contar la cantidad de ocurrencias para cada clase
count_df = comparison_df.apply(pd.Series.value_counts).fillna(0)

# Graficar el resultado
fig, ax = plt.subplots(figsize=(8, 6))
bars = count_df.plot(kind='bar', ax=ax, color=['skyblue', 'orange'])

# Agregar etiquetas con los valores en las barras
for bar in bars.patches:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 10, round(yval), ha='center', va='bottom', fontsize=10, color='black')

ax.set_xticklabels(count_df.index, rotation=0)
ax.set_ylabel('Cantidad')
ax.set_title('Comparación entre Valores Reales y Predicciones - Modelo 1')
plt.show()

# %% [markdown]
# <a id="4-2"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Modelo 2</h3>

# %% [markdown]
# *Para el siguiente modelo intentaremos mejorar nuestro modelo anterior agregando nuevas variables, como el cociente de las transacciones "Cociente_Trans_Amt_Ct", las diferencias entre cuatrimestres de los montos y las cantidades "Total_Amt_Chng_Q4_Q1" y "Total_Ct_Chng_Q4_Q1", y el saldo rotativo de la tarjeta de crédito "Total_Revolving_Bal".*

# %%
# Predictores: 
lista_predictores_2 = ['Cociente_Trans_Amt_Ct', 'Total_Trans_Amt_Group_Promedio', 'Total_Revolving_Bal', 
                     'Total_Amt_Chng_Q4_Q1', 'Total_Ct_Chng_Q4_Q1']

# Dividir los datos en conjunto de entrenamiento y conjunto de prueba (por ejemplo, 70% entrenamiento, 30% prueba)
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=422)
X_train = df_train[lista_predictores_2].values
y_train = df_train['Attrition_Flag'].values
X_test = df_test[lista_predictores_2].values
y_test = df_test['Attrition_Flag'].values

# Entrenar el modelo en el conjunto de entrenamiento
clf_2 = LogisticRegression()
clf_2.fit(X_train, y_train)

# Evaluar el modelo en el conjunto de prueba
y_pred = clf_2.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Precisión del modelo en el conjunto de prueba: {:.2f}%".format(accuracy * 100))

# Obtener las probabilidades predichas en lugar de las etiquetas de clase
y_prob_full = clf_2.predict_proba(df[lista_predictores_2])[:, 1]

# Agregar las probabilidades al DataFrame original
df['Probabilidad_Retencion_2'] = y_prob_full

# Obtener las probabilidades predichas en lugar de las etiquetas de clase
y_prob = clf_2.predict_proba(X_test)[:, 1]

print("Ajustemos el umbral para analizar posibles mejores resultados:")
# Ajustar el umbral que por defecto el algoritmo toma en 0.5
umbral = 0.4
y_pred_adjusted = (y_prob >= umbral).astype(int)

# Evaluar el modelo con el umbral ajustado
accuracy_adjusted = accuracy_score(y_test, y_pred_adjusted)
print("Precisión del modelo con umbral en {:.2f}: {:.2f}%".format(umbral, accuracy_adjusted * 100))

umbral = 0.6
y_pred_adjusted = (y_prob >= umbral).astype(int)

# Evaluar el modelo con el umbral ajustado
accuracy_adjusted = accuracy_score(y_test, y_pred_adjusted)
print("Precisión del modelo con umbral en {:.2f}: {:.2f}%".format(umbral, accuracy_adjusted * 100))
# Out:
# Precisión del modelo en el conjunto de prueba: 90.08%
# Ajustemos el umbral para analizar posibles mejores resultados:
# Precisión del modelo con umbral en 0.40: 89.39%
# Precisión del modelo con umbral en 0.60: 90.03%

# %% [markdown]
# *Hemos obtenido una mejor predicción en nuestro nuevo modelo, pero en este caso nuestro ajuste al umbral no mejora la predicción del algoritmo.*

# %%
# Definir la cuadrícula de hiperparámetros a explorar
param_grid = {
    'fit_intercept' : [True,False],
    'penalty': ['l1', 'l2','elasticnet','none'],
    'C':[0.001, 0.005, 0.01, 0.1, 1, 10],
    'max_iter':[50,80,100],
    'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
}

# Inicializar el modelo de regresión logística
clf_Hiper = LogisticRegression()

# Realizar la búsqueda grid con la función de puntuación de especificidad
grid_search = GridSearchCV(clf_Hiper, param_grid, cv=3, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Mostrar los mejores hiperparámetros encontrados
print("Mejores hiperparámetros:", grid_search.best_params_)

# Obtener el mejor modelo
best_model = grid_search.best_estimator_

# Evaluar el mejor modelo en el conjunto de prueba
y_pred_best = best_model.predict(X_test)
accuracy_best = accuracy_score(y_test, y_pred_best)
print("Precisión del mejor modelo en el conjunto de prueba: {:.2f}%".format(accuracy_best * 100))
# Out:
# Mejores hiperparámetros: {'C': 10, 'fit_intercept': True, 'max_iter': 50, 'penalty': 'l2', 'solver': 'liblinear'}
# Precisión del mejor modelo en el conjunto de prueba: 89.68%

# %% [markdown]
# *El ajuste nos muestra una leve caída de nuestro accuracy del modelo 2, por lo que omitiremos ajustar este modelo.*

# %% [markdown]
# <a id="4-2-1"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Modelo 2 - Matriz de Confusión</h3>

# %%
# Calcular la matriz de confusión para el conjunto de entrenamiento
confusion_train = confusion_matrix(y_train, clf_2.predict(X_train))

# Calcular la matriz de confusión para el conjunto de prueba
confusion_test = confusion_matrix(y_test, clf_2.predict(X_test))

# Imprimir las matrices de confusión
print("Matriz de Confusión para Datos de Entrenamiento:")
print(confusion_train)

print("Matriz de Confusión para Datos de Prueba:")
print(confusion_test)
# Out:
# Matriz de Confusión para Datos de Entrenamiento:
# [[ 695  621]
#  [ 235 6550]]
# Matriz de Confusión para Datos de Prueba:
# [[ 167  144]
#  [  57 1658]]

# %%
# Grafico
# Primero defino la estructura de mis gráficos a mostras
fig, ax = plt.subplots(nrows = 1,
                      ncols = 2,
                      figsize = (10,5)) 

# Luego indico lo que voy a dibujar en el primer cuadrante
sns.heatmap(confusion_test, 
            annot=True, fmt='d', cmap='Greens', cbar=False, 
            ax=ax[0])
ax[0].set_title('Testeo')
ax[0].set_xlabel('Predicción')
ax[0].set_ylabel('Real')

# Luego indico lo que voy a dibujar en el segundo cuadrante
sns.heatmap(confusion_train, 
            annot=True, fmt='d', cmap='Blues', cbar=False, 
            ax=ax[1])
ax[1].set_title('Entrenamiento')
ax[1].set_xlabel('Predicción')
ax[1].set_ylabel('Real')

# Muestra
plt.show()

# %% [markdown]
# *El modelo ha clasificado correctamente a 6550 clientes como retención (positivos) y a 621 como no retención (negativos) en el conjunto de entrenamiento. Cometió 695 errores al clasificar clientes que realmente retuvieron como no retención y 235 errores al clasificar clientes que realmente no retuvieron como retención.*
#
# *En el conjunto de prueba, el modelo acertó en clasificar correctamente a 1658 clientes como retención y a 144 clientes como no retención. Cometió 167 errores al clasificar clientes que realmente retuvieron como no retención y 57 errores al clasificar clientes que realmente no retuvieron como retención.*

# %%
# Calculemos las metricas, para eso vamos a guardar el resultado de cada cuadrante para utilizarlos 

# Paso 1: capturo cada uno de los elementos de la matriz de confusión 
Total_TEST = sum(sum(confusion_test))
Total_TRAIN = sum(sum(confusion_train))
TP_TEST = confusion_test[1,1]
TP_TRAIN = confusion_train[1,1]
TN_TEST = confusion_test[0,0]
TN_TRAIN = confusion_train[0,0]
FP_TEST = confusion_test[0,1]
FP_TRAIN = confusion_train[0,1]
FN_TEST = confusion_test[1,0]
FN_TRAIN = confusion_train[1,0]

# Paso 2: Calculo métricas
Precision_TEST = TP_TEST / (TP_TEST + FP_TEST)
Precision_TRAIN = TP_TRAIN / (TP_TRAIN + FP_TRAIN)
Recall_TEST = TP_TEST / (TP_TEST + FN_TEST)
Recall_TRAIN = TP_TRAIN / (TP_TRAIN + FN_TRAIN)
Accuracy_TEST = (TP_TEST + TN_TEST) / Total_TEST
Accuracy_TRAIN = (TP_TRAIN + TN_TRAIN) / Total_TRAIN
Especificidad_TEST = TN_TEST / (TN_TEST + FP_TEST)
Especificidad_TRAIN = TN_TRAIN / (TN_TRAIN + FP_TRAIN)

# Paso 3: Presento todo en una misma tabla 
metricas = pd.DataFrame(columns=['Poblacion', 'Metrica','Valor'])

# Precision
nuevo_dato = {'Poblacion': 'TEST', 
              'Metrica': 'Precision',
              'Valor': Precision_TEST}
metricas.loc[len(metricas)] = nuevo_dato
nuevo_dato = {'Poblacion': 'TRAIN', 
              'Metrica': 'Precision',
              'Valor': Precision_TRAIN}
metricas.loc[len(metricas)] = nuevo_dato

# Recall
nuevo_dato = {'Poblacion': 'TEST', 
              'Metrica': 'Recall',
              'Valor': Recall_TEST}
metricas.loc[len(metricas)] = nuevo_dato
nuevo_dato = {'Poblacion': 'TRAIN', 
              'Metrica': 'Recall',
              'Valor': Recall_TRAIN}
metricas.loc[len(metricas)] = nuevo_dato

# Accurancy
nuevo_dato = {'Poblacion': 'TEST', 
              'Metrica': 'Accurancy',
              'Valor': Accuracy_TEST}
metricas.loc[len(metricas)] = nuevo_dato
nuevo_dato = {'Poblacion': 'TRAIN', 
              'Metrica': 'Accurancy',
              'Valor': Accuracy_TRAIN}
metricas.loc[len(metricas)] = nuevo_dato

# Especificidad
nuevo_dato = {'Poblacion': 'TEST', 
              'Metrica': 'Especificidad',
              'Valor': Especificidad_TEST}
metricas.loc[len(metricas)] = nuevo_dato
nuevo_dato = {'Poblacion': 'TRAIN', 
              'Metrica': 'Especificidad',
              'Valor': Especificidad_TRAIN}
metricas.loc[len(metricas)] = nuevo_dato

# Paso 4: Grafico 
plt.figure(figsize=(12, 5))
sns.barplot(data = metricas,
                x = 'Metrica',
                y = 'Valor',
                hue = 'Poblacion')
plt.xlabel('Tipo de Métrica')
plt.ylabel('Valor de la Métrica')
plt.title('Métricas - MODELO 1')
ax = plt.gca()
for p in ax.patches:
    x_text = p.get_x() + p.get_width() / 2.0  # Calcula la posición x del texto
    y_text = p.get_height()  # Toma la altura de la columna
    ax.text(x_text, y_text, f'{str(round(y_text,2) * 100)}%', # Indica posición x e y, y texto a mostrar 
            ha = 'center', # Alineación horizontal 
            va = 'bottom',  # Alineación vertical
            fontsize = 10, color = 'black', fontweight = 'bold')

plt.legend(loc='lower right')    
metricas_1 = plt.gcf()
plt.show()

# %% [markdown]
# *El modelo parece tener un buen rendimiento general con altas precisiones y recalls, indicando que es capaz de clasificar tanto los casos positivos como negativos de manera efectiva. La especificidad es relativamente baja, lo que sugiere que el modelo podría tener más dificultades para identificar correctamente los casos negativos en comparación con los casos positivos. En general, los resultados sugieren que el modelo es sólido en la identificación de casos positivos, pero puede haber margen para mejorar la identificación de casos negativos, según la métrica de especificidad. La elección de umbral (threshold) también puede ser relevante para ajustar el equilibrio entre precisión y recall, dependiendo de los requisitos específicos del problema.*

# %% [markdown]
# <a id="4-2-2"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Validación del Modelo 2</h3>

# %% [markdown]
# <a id="4-2-3"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Métricas de Entrenamiento y Prueba - Modelo 2</h3>

# %%
# Predecir en el conjunto de entrenamiento
y_train_pred = clf_2.predict(X_train)

# Calcular la precisión en el conjunto de entrenamiento
accuracy_train = accuracy_score(y_train, y_train_pred)

# Predecir en el conjunto de prueba
y_test_pred = clf_2.predict(X_test)

# Calcular la precisión en el conjunto de prueba
accuracy_test = accuracy_score(y_test, y_test_pred)

# Imprimir las métricas de precisión
print("Precisión en el conjunto de entrenamiento: {:.2f}%".format(accuracy_train * 100))
print("Precisión en el conjunto de prueba: {:.2f}%".format(accuracy_test * 100))
# Out:
# Precisión en el conjunto de entrenamiento: 89.43%
# Precisión en el conjunto de prueba: 90.08%

# %% [markdown]
# <a id="4-2-4"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">K-fold Cross-Validation - Validación Cruzada - Modelo 2</h3>

# %%
X = df[lista_predictores_2].values
y = df['Attrition_Flag'].values

# Configurar K-fold Cross-Validation con 5 pliegues
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# Realizar validación cruzada
cv_scores = cross_val_score(clf_2, X, y, cv=kfold, scoring='accuracy')

# Imprimir los resultados de la validación cruzada
print("Precisión de validación cruzada:")
for i, score in enumerate(cv_scores, start=1):
    print("Pliegue {}: {:.2f}%".format(i, score * 100))

print("\nPrecisión promedio: {:.2f}% (+/- {:.2f}%)".format(np.mean(cv_scores) * 100, np.std(cv_scores) * 100))
# Out:
# Precisión de validación cruzada:
# Pliegue 1: 89.88%
# Pliegue 2: 88.89%
# Pliegue 3: 89.14%
# Pliegue 4: 89.19%
# Pliegue 5: 90.81%
#
# Precisión promedio: 89.58% (+/- 0.70%)

# %% [markdown]
# *El Modelo 2 muestra una mejora significativa en la precisión promedio durante la validación cruzada en comparación con el Modelo 1. La precisión promedio del Modelo 2 es más alta en cada uno de los pliegues, lo que indica que el Modelo 2 es más consistente en su rendimiento a lo largo de diferentes conjuntos de datos de entrenamiento y prueba.*
#
# *La validación cruzada del Modelo 2 sugiere que este modelo tiene una capacidad más robusta y generaliza mejor en comparación con el Modelo 1. La mayor precisión promedio en la validación cruzada indica que el Modelo 2 es más confiable en diferentes conjuntos de datos, lo que es una característica positiva para su implementación en la retención de clientes.*

# %% [markdown]
# <a id="4-2-5"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">AUC - Curva ROC - Modelo 2</h3>

# %%
# Calcular la curva ROC y el AUC para el conjunto de prueba (test)
y_pred_prob_test = clf_2.predict_proba(X_test)[:, 1]  # Probabilidades de pertenecer a la clase positiva
fpr_test, tpr_test, thresholds_test = roc_curve(y_test, y_pred_prob_test)
roc_auc_test = roc_auc_score(y_test, y_pred_prob_test)

# %%
# Calcular la curva ROC y el AUC para el conjunto de entrenamiento (train)
y_pred_prob_train = clf_2.predict_proba(X_train)[:, 1]  # Probabilidades de pertenecer a la clase positiva
fpr_train, tpr_train, thresholds_train = roc_curve(y_train, y_pred_prob_train)
roc_auc_train = roc_auc_score(y_train, y_pred_prob_train)

# %%
# Crear el gráfico con ambas curvas ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr_test, tpr_test, color='darkorange', lw=2, label='Test ROC curve (AUC = %0.2f)' % roc_auc_test)
plt.plot(fpr_train, tpr_train, color='green', lw=2, label='Train ROC curve (AUC = %0.2f)' % roc_auc_train)
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# *El AUC de 0.91 para el conjunto de prueba y 0.90 para el conjunto de entrenamiento indica una excelente capacidad de discriminación del Modelo 2.*
#
# *El Modelo 2 tiene un rendimiento muy bueno en la clasificación de clientes que retienen y aquellos que no retienen. La capacidad de discriminación cercana a 1 sugiere que el modelo es eficaz en distinguir entre las clases objetivo, lo cual es esencial para el éxito en la retención de clientes.*

# %%
# Crear un DataFrame con las predicciones y los valores reales
comparison_df = pd.DataFrame({'Real': y_test, 'Predicción': y_pred})

# Contar la cantidad de ocurrencias para cada clase
count_df = comparison_df.apply(pd.Series.value_counts).fillna(0)

# Graficar el resultado
fig, ax = plt.subplots(figsize=(8, 6))
bars = count_df.plot(kind='bar', ax=ax, color=['skyblue', 'orange'])

# Agregar etiquetas con los valores en las barras
for bar in bars.patches:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 10, round(yval), ha='center', va='bottom', fontsize=10, color='black')

ax.set_xticklabels(count_df.index, rotation=0)
ax.set_ylabel('Cantidad')
ax.set_title('Comparación entre Valores Reales y Predicciones - Modelo 2')
plt.show()

# %% [markdown]
# <a id="4-3"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Regresión Logística - Conclusiones</h3>

# %% [markdown]
# *Comparación y Conclusiones:*
#
# *El Modelo 2 supera significativamente al Modelo 1 en todas las métricas de evaluación, mostrando una mejora sustancial en la capacidad de clasificación y precisión.*
#
# *El aumento en la especificidad en el Modelo 2 (54%) sugiere una mejor capacidad para identificar verdaderos negativos, reduciendo los falsos positivos en comparación con el Modelo 1 (26%).*
#
# *La validación cruzada también respalda la robustez del Modelo 2, con una precisión promedio del 89.55%, lo cual es más alto que la del Modelo 1 (85.99%).*
#
# *Ambos modelos muestran AUCs sólidos, indicando una excelente capacidad de discriminación. Sin embargo, el Modelo 2 alcanza un AUC ligeramente superior (0.91) en comparación con el Modelo 1 (0.87).*
#
# *Recomendaciones:*
#
# *Basándonos en estas métricas, se recomienda preferir el Modelo 2 para predecir la retención de clientes, ya que ofrece un rendimiento más robusto y preciso en la clasificación. Es crucial considerar la especificidad en este contexto para evitar falsas alarmas sobre clientes que podrían retenerse. Se sugiere ajustar aún más los umbrales según los requisitos específicos del negocio.*

# %% [markdown]
# <a id="5"></a>
# <h1 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">RandomForest</h1>

# %% [markdown]
# *Si bien obtuvimos buenos resultados con la regresión logística, probaremos a continuación otro modelo, el RandomForest. Para ello haremos un primer modelo con todas las variables menos aquellas que producierian un sobreajuste del modelo.*

# %% [markdown]
# <a id="5-1"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Modelo Random Forest</h3>

# %%
df = df.sample(frac = 1).reset_index(drop = True) #To shuffle data

# Lista de columnas a excluir
columnas_excluidas = ['Attrition_Flag', 'CLIENTNUM', 'Es_Cliente', 'Probabilidad_Retencion_1', 'Probabilidad_Retencion_2']

# Obtener el listado completo de columnas excluyendo las especificadas
lista_predictores_3 = [col for col in df.columns if col not in columnas_excluidas]

X_train = df_train[lista_predictores_3].values
y_train = df_train['Attrition_Flag'].values
X_test = df_test[lista_predictores_3].values
y_test = df_test['Attrition_Flag'].values

# %%
# Crear el modelo
rf_model = RandomForestClassifier(n_estimators = 150, 
                                  random_state = 42,
                                  max_depth = 5,
                                  min_samples_leaf = 100,
                                  max_features = 6,
                                  criterion = 'entropy')

# Entrenar el modelo
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=5, max_features=6,
#                        min_samples_leaf=100, n_estimators=150, random_state=42)

# %%
# Realizar predicciones en el conjunto de prueba
y_pred = rf_model.predict(X_test)

# Evaluar la precisión del modelo
accuracy = accuracy_score(y_test, y_pred)
print(f'Precisión del modelo: {accuracy * 100:.2f}%')

# Mostrar la matriz de confusión y el informe de clasificación
print('\nMatriz de Confusión:')
print(confusion_matrix(y_test, y_pred))

print('\nInforme de Clasificación:')
print(classification_report(y_test, y_pred))
# Out:
# Precisión del modelo: 91.56%
#
# Matriz de Confusión:
# [[ 171  140]
#  [  31 1684]]
#
# Informe de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.85      0.55      0.67       311
#            1       0.92      0.98      0.95      1715
#
#     accuracy                           0.92      2026
#    macro avg       0.88      0.77      0.81      2026
# weighted avg       0.91      0.92      0.91      2026

# %% [markdown]
# *La precisión general del modelo es buena, pero la precisión para la clase 0 (clientes que no abandonan) es un poco más baja. El recall para la clase 0 es relativamente bajo, lo que sugiere que el modelo tiende a perder clientes que realmente no abandonan. El modelo tiene un buen rendimiento en la identificación de clientes que abandonan (clase 1), como se refleja en un alto recall y precision.*

# %% [markdown]
# *Ahora veamos cuales son las features mas importantes del modelo y ajustemos los hiperparámetros para armar un nuevo modelo de randomforest con estos nuevos parámetros.*

# %% [markdown]
# <a id="5-2"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Features Importances</h3>

# %%
# Obtener la importancia de las características
feature_importances = rf_model.feature_importances_

# Crear un DataFrame para mostrar las importancias de las características
feature_df = pd.DataFrame({'Feature': lista_predictores_3, 'Importance': feature_importances})

# Ordenar el DataFrame por importancia de características
feature_df = feature_df.sort_values(by='Importance', ascending=False)

# Tomar las 15 características más importantes
top_15_features = feature_df.head(15)

plt.figure(figsize=(10, 6))
plt.barh(top_15_features['Feature'], top_15_features['Importance'], color="#CB4335")
plt.xlabel('Importancia')
plt.title('Las 15 Características Más Importantes en el Modelo Random Forest')
plt.show()

# %% [markdown]
# <a id="5-3"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Ajuste de Hiperparametros</h3>

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [5, 8, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

rf_model = RandomForestClassifier(random_state=42)

# Utilizar RandomizedSearchCV
random_search = RandomizedSearchCV(rf_model, param_distributions=param_grid, n_iter=10, cv=3, random_state=42)
random_search.fit(X_train, y_train)

# Mostrar los mejores parámetros
print("Mejores parámetros:", random_search.best_params_)
# Out:
# Mejores parámetros: {'n_estimators': 200, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_depth': 10}

# %% [markdown]
# <a id="5-4"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">RandomForest Nuevo Modelo Ajustado</h3>

# %% [markdown]
# *Iniciamos el nuevo modelo con las mejores features. Estamos omitiendo aquellos que representan a los mismos datos base o transformaciones de estos para evitar el sobreajuste.*

# %%
df = df.sample(frac = 1).reset_index(drop = True) #To shuffle data

lista_predictores_4 = ['Total_Trans_Amt_Group_Promedio', 'Total_Revolving_Bal', 
                       'Total_Trans_Ct', 'Avg_Utilization_Ratio', 'Credit_Limit', 'Total_Relationship_Count',
                       'Total_Ct_Chng_Q4_Q1', 'Total_Amt_Chng_Q4_Q1']

X_train = df_train[lista_predictores_4].values
y_train = df_train['Attrition_Flag'].values
X_test = df_test[lista_predictores_4].values
y_test = df_test['Attrition_Flag'].values

# %% [markdown]
# *Este nuevo modelo usa los mejores hiperparámetros obtenidos anteriormente y las mejores features.*

# %%
# Crear el modelo
rf_model = RandomForestClassifier(n_estimators = 200, 
                                  max_depth = 10,
                                  min_samples_leaf = 2,
                                  min_samples_split=10,
                                  max_features = 6,
                                  random_state = 43,
                                  criterion = 'entropy')

# Entrenar el modelo
rf_model.fit(X_train, y_train)

# Realizar predicciones en el conjunto de prueba
y_pred = rf_model.predict(X_test)

df_test['RF_Predicted_Attrition_Flag'] = y_pred

# Evaluar la precisión del modelo
accuracy = accuracy_score(y_test, y_pred)
print(f'Precisión del modelo de testeo: {accuracy * 100:.2f}%')

# Realizar predicciones en el conjunto de entrenamiento
y_pred_2 = rf_model.predict(X_train)

# Agregar las predicciones a los conjuntos de datos
df_train['RF_Predicted_Attrition_Flag'] = y_pred_2

accuracy = accuracy_score(y_train, y_pred_2)
print(f'Precisión del modelo de entrenamiento: {accuracy * 100:.2f}%')

# Mostrar la matriz de confusión y el informe de clasificación
print('\nMatriz de Confusión:')
print(confusion_matrix(y_test, y_pred))

print('\nInforme de Clasificación:')
print(classification_report(y_test, y_pred))
# Out:
# Precisión del modelo de testeo: 94.03%
# Precisión del modelo de entrenamiento: 96.28%
#
# Matriz de Confusión:
# [[ 242   69]
#  [  52 1663]]
#
# Informe de Clasificación:
#               precision    recall  f1-score   support
#
#            0       0.82      0.78      0.80       311
#            1       0.96      0.97      0.96      1715
#
#     accuracy                           0.94      2026
#    macro avg       0.89      0.87      0.88      2026
# weighted avg       0.94      0.94      0.94      2026

# %% [markdown]
# *Precision: De los casos que el modelo clasificó como positivos, el 96% realmente son positivos.*
# *Recall (Sensibilidad): De todos los casos positivos reales, el 97% fueron identificados correctamente.*
# *F1-score:* Combina precisión y recall en una sola métrica, proporcionando un equilibrio entre ambas. En este caso, es 0.96 para la clase 1 y 0.80 para la clase 0.*
# *El modelo ha mejorado en comparación con el modelo anterior, con una mayor precisión general y mejor rendimiento en las métricas de clase. La precisión y recall para ambas clases son altos, lo que sugiere un modelo robusto en la clasificación de ambas clases. El modelo parece generalizar bien a nuevos datos, ya que mantiene un alto rendimiento en el conjunto de prueba.*
# *En resumen, este nuevo modelo parece ser una mejora significativa, probablemente debido a la selección de características importantes y la optimización de hiperparámetros.*

# %% [markdown]
# <a id="5-5"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">AUC/ROC RandomForest</h3>

# %%
# Definir la función de especificidad
def specificity_score(y_true, y_pred):
    tn, fp, _, _ = confusion_matrix(y_true, y_pred).ravel()
    specificity = tn / (tn + fp)
    return specificity

# Realizar predicciones en el conjunto de entrenamiento
y_train_pred = rf_model.predict(X_train)
y_test_pred = rf_model.predict(X_test)

# Obtener las probabilidades predichas en lugar de las etiquetas de clase
y_train_prob = rf_model.predict_proba(X_train)[:, 1]
y_test_prob = rf_model.predict_proba(X_test)[:, 1]

# Calcular las métricas para el conjunto de entrenamiento
accuracy_train = accuracy_score(y_train, y_train_pred)
precision_train, recall_train, f1_train, _ = precision_recall_fscore_support(y_train, y_train_pred, average='binary')
specificity_train = specificity_score(y_train, y_train_pred)

# Calcular las métricas para el conjunto de prueba
accuracy_test = accuracy_score(y_test, y_test_pred)
precision_test, recall_test, f1_test, _ = precision_recall_fscore_support(y_test, y_test_pred, average='binary')
specificity_test = specificity_score(y_test, y_test_pred)

# Calcular las curvas ROC
fpr_train, tpr_train, _ = roc_curve(y_train, y_train_prob)
roc_auc_train = auc(fpr_train, tpr_train)

fpr_test, tpr_test, _ = roc_curve(y_test, y_test_prob)
roc_auc_test = auc(fpr_test, tpr_test)

# Mostrar las métricas
print('Métricas para el Conjunto de Entrenamiento:')
print(f'Precisión: {accuracy_train * 100:.2f}%')
print(f'Precision: {precision_train:.2f}')
print(f'Recall: {recall_train:.2f}')
print(f'Especificidad: {specificity_train:.2f}')
print(f'F1-Score: {f1_train:.2f}')
print(f'AUC/ROC: {roc_auc_train:.2f}')

print('\nMétricas para el Conjunto de Prueba:')
print(f'Precisión: {accuracy_test * 100:.2f}%')
print(f'Precision: {precision_test:.2f}')
print(f'Recall: {recall_test:.2f}')
print(f'Especificidad: {specificity_test:.2f}')
print(f'F1-Score: {f1_test:.2f}')
print(f'AUC/ROC: {roc_auc_test:.2f}')

# Graficar las curvas ROC
plt.figure(figsize=(10, 6))
plt.plot(fpr_train, tpr_train, color='darkorange', lw=2, label=f'Train ROC Curve (AUC = {roc_auc_train:.2f})')
plt.plot(fpr_test, tpr_test, color='darkgreen', lw=2, label=f'Test ROC Curve (AUC = {roc_auc_test:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Curvas ROC para Train y Test')
plt.legend(loc='lower right')
plt.show()
# Out:
# Métricas para el Conjunto de Entrenamiento:
# Precisión: 96.28%
# Precision: 0.97
# Recall: 0.98
# Especificidad: 0.86
# F1-Score: 0.98
# AUC/ROC: 0.99
#
# Métricas para el Conjunto de Prueba:
# Precisión: 94.03%
# Precision: 0.96
# Recall: 0.97
# Especificidad: 0.78
# F1-Score: 0.96
# AUC/ROC: 0.97

# %% [markdown]
# *La alta precisión y AUC/ROC en el conjunto de entrenamiento en comparación con el conjunto de prueba podría sugerir sobreajuste. Validemos este modelo con validación cruzada.*

# %% [markdown]
# <a id="5-6"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Validación Cruzada RandomForest</h3>

# %%
# Realizar validación cruzada
cv_scores = cross_val_score(rf_model, X_train, y_train, cv=5, scoring='roc_auc')

# Mostrar los puntajes de validación cruzada
print(f"Puntajes de Validación Cruzada: {cv_scores}")
print(f"Puntaje Promedio: {cv_scores.mean()}")

# Graficar las curvas ROC para el conjunto de entrenamiento y prueba
plt.figure(figsize=(10, 6))
plt.plot(fpr_train, tpr_train, color='darkorange', lw=2, label=f'Train ROC Curve (AUC = {roc_auc_train:.2f})')
plt.plot(fpr_test, tpr_test, color='darkgreen', lw=2, label=f'Test ROC Curve (AUC = {roc_auc_test:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Curvas ROC para Train y Test')
plt.legend(loc='lower right')
plt.show()
# Out:
# Puntajes de Validación Cruzada: [0.97390914 0.97271716 0.96899614 0.97303939 0.96946967]
# Puntaje Promedio: 0.9716262978349303

# %% [markdown]
# <a id="5-7"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Conclusiones RandomForest</h3>

# %% [markdown]
# *Validación Cruzada: Los puntajes de validación cruzada son altos y consistentes (promedio de 0.971), lo cual es una buena señal de que el modelo generaliza bien en diferentes particiones del conjunto de entrenamiento.*
#
# *Curvas ROC: Las curvas ROC para el conjunto de prueba y entrenamiento son bastante similares, lo cual es positivo. No hay un claro indicio de sobreajuste en las curvas ROC.*
#
# *Matriz de Confusión y Otras Métricas: La matriz de confusión, precisión, recall y otras métricas en el conjunto de prueba parecen razonables y equilibradas.*

# %% [markdown]
# <a id="6"></a>
# <h1 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Modelo KNN - K-Nearest Neighbors</h1>

# %%
X_train = df_train[lista_predictores_4].values
y_train = df_train['Attrition_Flag'].values
X_test = df_test[lista_predictores_4].values
y_test = df_test['Attrition_Flag'].values

# Genero y entreno
knn_model = KNeighborsClassifier(n_neighbors = 5,
                            metric='euclidean')

# Entrenar el modelo
knn_model .fit(X_train, y_train)

# Realizar predicciones en el conjunto de prueba
y_test_pred = knn_model.predict(X_test)
y_train_pred = knn_model.predict(X_train)

# Obtener las probabilidades predichas en lugar de las etiquetas de clase
y_test_prob = knn_model.predict_proba(X_test)[:, 1]
y_train_prob = knn_model.predict_proba(X_train)[:, 1]

# %%
# Calcular las métricas para el conjunto de entrenamiento
accuracy_train = accuracy_score(y_train, y_train_pred)
precision_train, recall_train, f1_train, _ = precision_recall_fscore_support(y_train, y_train_pred, average='binary')
specificity_train = specificity_score(y_train, y_train_pred)

# Calcular las métricas para el conjunto de prueba
accuracy_test = accuracy_score(y_test, y_test_pred)
precision_test, recall_test, f1_test, _ = precision_recall_fscore_support(y_test, y_test_pred, average='binary')
specificity_test = specificity_score(y_test, y_test_pred)

# Mostrar las métricas
print('Métricas para el Conjunto de Entrenamiento:')
print(f'Accuracy: {accuracy_train * 100:.2f}%')
print(f'Precision: {precision_train:.2f}')
print(f'Recall: {recall_train:.2f}')
print(f'Specificity: {specificity_train:.2f}')
print(f'F1-Score: {f1_train:.2f}')
print(f'AUC/ROC: {roc_auc_train:.2f}')

print('\nMétricas para el Conjunto de Prueba:')
print(f'Accuracy: {accuracy_test * 100:.2f}%')
print(f'Precision: {precision_test:.2f}')
print(f'Recall: {recall_test:.2f}')
print(f'Specificity: {specificity_test:.2f}')
print(f'F1-Score: {f1_test:.2f}')
print(f'AUC/ROC: {roc_auc_test:.2f}')
# Out:
# Métricas para el Conjunto de Entrenamiento:
# Accuracy: 89.99%
# Precision: 0.92
# Recall: 0.97
# Specificity: 0.54
# F1-Score: 0.94
# AUC/ROC: 0.99
#
# Métricas para el Conjunto de Prueba:
# Accuracy: 85.98%
# Precision: 0.90
# Recall: 0.94
# Specificity: 0.40
# F1-Score: 0.92
# AUC/ROC: 0.97

# %% [markdown]
# <a id="6-1"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Validación Cruzada KNN - K-Nearest Neighbors</h3>

# %%
# Realizar validación cruzada
cv_scores = cross_val_score(knn_model, X_train, y_train, cv=5, scoring='accuracy')

# Mostrar los puntajes de validación cruzada
print("Puntajes de Validación Cruzada:", cv_scores)
print("Puntaje Promedio:", cv_scores.mean())
# Out:
# Puntajes de Validación Cruzada: [0.8618137  0.85617284 0.85864198 0.86296296 0.86296296]
# Puntaje Promedio: 0.8605108871981173

# %%
# Graficar las curvas ROC
plt.figure(figsize=(10, 6))
plt.plot(fpr_train, tpr_train, color='darkorange', lw=2, label=f'Train ROC Curve (AUC = {roc_auc_train:.2f})')
plt.plot(fpr_test, tpr_test, color='darkgreen', lw=2, label=f'Test ROC Curve (AUC = {roc_auc_test:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlabel('Tasa de Falsos Positivos')
plt.ylabel('Tasa de Verdaderos Positivos')
plt.title('Curvas ROC para Train y Test')
plt.legend(loc='lower right')

plt.show()

# %% [markdown]
# <a id="6-2"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Conclusiones KNN - K-Nearest Neighbors</h3>

# %% [markdown]
# *Métricas para el Conjunto de Entrenamiento:*
#
# *Accuracy: El modelo clasifica correctamente alrededor del 89.99% de todas las muestras del conjunto de entrenamiento.*
# *Precision: De todas las muestras que el modelo predijo como positivas, alrededor del 92% realmente son positivas. Es decir, cuando el modelo predice que un cliente retiene, tiene una precisión del 92%.*
# *Recall: El modelo identifica correctamente alrededor del 97% de todas las muestras positivas reales en el conjunto de entrenamiento. Es decir, de todos los clientes que realmente retienen, el modelo identifica correctamente al 97%.*
# *Specificity: El modelo identifica correctamente alrededor del 54% de todas las muestras negativas reales en el conjunto de entrenamiento. Es decir, de todos los clientes que realmente no retienen, el modelo identifica correctamente al 54%.*
# *F1-Score: Es una medida que combina precisión y recall en un solo valor. Un valor de 0.94 indica un buen equilibrio entre precisión y recall en el conjunto de entrenamiento.*
# *AUC/ROC: El área bajo la curva ROC es 0.99, lo que indica un buen rendimiento del modelo para distinguir entre las clases positivas y negativas en el conjunto de entrenamiento.*
#
# *Métricas para el Conjunto de Prueba:*
#
# *Accuracy: El modelo clasifica correctamente alrededor del 85.98% de todas las muestras del conjunto de prueba.*
# *Precision: De todas las muestras que el modelo predijo como positivas, alrededor del 90% realmente son positivas. Es decir, cuando el modelo predice que un cliente retiene, tiene una precisión del 90%.*
# *Recall: El modelo identifica correctamente alrededor del 94% de todas las muestras positivas reales en el conjunto de prueba. Es decir, de todos los clientes que realmente retienen, el modelo identifica correctamente al 94%.*
# *Specificity: El modelo identifica correctamente alrededor del 40% de todas las muestras negativas reales en el conjunto de prueba. Es decir, de todos los clientes que realmente no retienen, el modelo identifica correctamente al 40%.*
# *F1-Score: Es una medida que combina precisión y recall en un solo valor. Un valor de 0.92 indica un buen equilibrio entre precisión y recall en el conjunto de prueba.*
# *AUC/ROC: El área bajo la curva ROC es 0.97, lo que indica un buen rendimiento del modelo para distinguir entre las clases positivas y negativas en el conjunto de prueba.*
#
# *Puntajes de Validación Cruzada:*
#
# *Los puntajes de validación cruzada muestran la precisión del modelo en diferentes divisiones de los datos de entrenamiento. El puntaje promedio de validación cruzada es aproximadamente 0.86, lo que indica que el modelo tiene un rendimiento consistente en diferentes divisiones de los datos de entrenamiento.*
#
# *En general, los resultados indican que el modelo KNN tiene un buen rendimiento en la clasificación de clientes que retienen y no retienen en el conjunto de entrenamiento y prueba, con un ligero sobreajuste observado en la especificidad del conjunto de prueba en comparación con el conjunto de entrenamiento. Además, el rendimiento del modelo es consistente en diferentes divisiones de los datos de entrenamiento según la validación cruzada.*

# %% [markdown]
# <a id="7"></a>
# <h1 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Feature Engineering</h1>

# %% [markdown]
# *Iniciemos una nueva etapa de Feature Engineering en busca de nuevas features que puedan ayudarnos con nuestro modelo. Para ello utilizaremos la aprendido en clase: Principal Component Analysis (PCA), Kernel PCA y Análisis Factorial.*

# %% [markdown]
# <a id="7-1"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Principal Component Analysis (PCA)</h3>

# %%
# Inicio el objeto PCA
pca = PCA(4)
# Genero componentes con TRAIN
PCA_train = pca.fit_transform(X_train)
# Aplico a test
PCA_test = pca.transform(X_test)

# Almaceno en dataframe y presento
# Train
PCA_train = pd.DataFrame(data = PCA_train)
prefijo = "PC_"
PCA_train = PCA_train.add_prefix(prefijo)
# Test
PCA_test = pd.DataFrame(data = PCA_test)
prefijo = "PC_"
PCA_test = PCA_test.add_prefix(prefijo)
# ¿Qué generé?
PCA_train.head()
# Out:
#       PC_0     PC_1   PC_2  PC_3
# 0 -6897.88   -28.98 -22.40  3.26
# 1 24334.24  1266.80 -55.04 -1.61
# 2 -3855.57    45.57  16.83  1.59
# 3 -3646.50  -202.23  17.15 -0.43
# 4 -6160.05 -1134.70  29.19  0.38

# %%
# Análisis de la varianza explicada para cada componente
varianza_explicada = pca.explained_variance_ratio_
componentes = PCA_train.columns

plt.bar(componentes, 
        varianza_explicada)
plt.xlabel('Componente Principal')
plt.ylabel('Varianza Explicada')
plt.title('Varianza Explicada por Componente Principal')
ax = plt.gca()
for p in ax.patches:
    x_text = p.get_x() + p.get_width() / 2.0  # Calcula la posición x del texto
    y_text = p.get_height()  # Toma la altura de la columna
    ax.text(x_text, y_text, f'{str(round(y_text * 100,2))}%', # Indica posición x e y, y texto a mostrar 
            ha = 'center', # Alineación horizontal 
            va = 'bottom',  # Alineación vertical
            fontsize = 10, color = 'black', fontweight = 'bold')
plt.show()

# %% [markdown]
# *Se utilizaron 4 componentes principales (PC) para el análisis de PCA.*
#
# *Se generaron componentes tanto para el conjunto de entrenamiento como para el conjunto de prueba.*
#
# *El gráfico de varianza explicada por cada componente muestra que el primer componente (PC_0) captura el 99.21% de la varianza, mientras que el segundo componente (PC_1) captura solo el 0.79%. Los componentes restantes (PC_2 y PC_3) no aportan varianza adicional. Esto sugiere que la mayoría de la variabilidad de los datos está capturada por el primer componente.*

# %% [markdown]
# <a id="7-2"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Kernel PCA</h3>

# %%
# Inicio el objeto KPCA
Kpca = KernelPCA(n_components = 4, 
                 kernel = 'sigmoid', 
                 gamma = 0.2)
# Genero componentes con TRAIN
KPCA_train = Kpca.fit_transform(X_train)
# Aplico a test
KPCA_test = Kpca.transform(X_test)

# Almaceno en dataframe y presento
# Train
KPCA_train = pd.DataFrame(data = KPCA_train)
prefijo = "KPC_"
KPCA_train = KPCA_train.add_prefix(prefijo)
# Test
KPCA_test = pd.DataFrame(data = KPCA_test)
prefijo = "KPC_"
KPCA_test = KPCA_test.add_prefix(prefijo)
# ¿Qué generé?
KPCA_test.head()
# Out:
#    KPC_0  KPC_1  KPC_2  KPC_3
# 0   0.00   0.00   0.00   0.00
# 1   0.00   0.00   0.00   0.00
# 2   0.00   0.00   0.00   0.00
# 3   0.00   0.00   0.00   0.00
# 4   0.00   0.00   0.00   0.00

# %% [markdown]
# *Se utilizaron 4 componentes principales kernelizados (KPC) utilizando una función de kernel sigmoidal con un parámetro gamma de 0.2.*
#
# *Al igual que en PCA, se generaron componentes tanto para el conjunto de entrenamiento como para el conjunto de prueba.*

# %% [markdown]
# <a id="7-3"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Ánalisis Factorial</h3>

# %%
# Inicializar el analizador factorial con un número máximo de factores (puedes ajustar según sea necesario)
max_factors = len(lista_predictores_4) - 1  
fa = FactorAnalyzer(n_factors = max_factors, 
                    rotation = None)

# Ajustar el modelo al conjunto de datos
fa.fit(X_train)

# Obtener los valores propios (eigenvalues)
eigenvalues, _ = fa.get_eigenvalues()

# Crear el Scree Plot
plt.plot(np.arange(1, len(lista_predictores_4) + 1), eigenvalues, marker='o')
plt.title('Scree Plot')
plt.xlabel('Número de Factores')
plt.ylabel('Valor Propio')
plt.show()

# %% [markdown]
# *Se utilizó un análisis factorial con un máximo de 7 factores (uno menos que el número de variables predictoras originales) para el análisis de AF.*
#
# *El scree plot muestra que los primeros 4 factores tienen valores propios (eigenvalues) superiores a 1, lo que sugiere que estos factores explican una cantidad significativa de varianza en los datos.*

# %%
# Genero mi modelo 
n_factores = 4
fa = FactorAnalyzer(n_factors = n_factores, 
                    is_corr_matrix = False)
fa.fit(X_train)
# Out:
# FactorAnalyzer(n_factors=4, rotation_kwargs={})

# %%
# Obtenemos las cargas
cargas_factoriales = pd.DataFrame({'Features': lista_predictores_4})
cargas_factoriales_values = pd.DataFrame(fa.loadings_)
prefijo = "CargaFactorial_"
cargas_factoriales_values = cargas_factoriales_values.add_prefix(prefijo)
cargas_factoriales = pd.concat([cargas_factoriales,cargas_factoriales_values],axis = 1)
print("Cargas de los factores:")
cargas_factoriales
# Out:
# Cargas de los factores:
#                          Features  CargaFactorial_0  CargaFactorial_1  \
# 0  Total_Trans_Amt_Group_Promedio              0.70             -0.04
# 1             Total_Revolving_Bal             -0.03              0.91
# 2                  Total_Trans_Ct              1.01              0.03
# 3           Avg_Utilization_Ratio              0.07              0.68
# 4                    Credit_Limit             -0.07              0.10
# 5        Total_Relationship_Count             -0.16             -0.01
# 6             Total_Ct_Chng_Q4_Q1              0.14             -0.02
# 7            Total_Amt_Chng_Q4_Q1             -0.01              0.02
#
#    CargaFactorial_2  CargaFactorial_3
# 0              0.10             -0.18
# 1              0.04              0.20
# 2              0.06              0.02
# 3             -0.06             -0.57
# 4              0.09              0.78
# 5              0.07             -0.11
# 6              0.91              0.03
# ...

# %%
# Visualmente
cargas_factoriales_long = cargas_factoriales.melt(id_vars='Features', 
                                                  var_name='Factor', 
                                                  value_name='CargaFactorial')

sns.barplot(data = cargas_factoriales_long,
                x = 'Features',
                y = 'CargaFactorial',
                hue = 'Factor')

plt.title('Cargas Factoriales por Variable')
plt.xlabel('Cargas Factoriales')
plt.ylabel('Factores')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %% [markdown]
# *Se obtuvieron las cargas factoriales para los 4 factores. Las cargas factoriales indican la correlación entre las variables originales y los factores latentes. Las variables con cargas factoriales más altas en un factor son las más relevantes para ese factor.*

# %%
# Generamos dataframes con las puntuaciones de factores
# representan la contribución de cada observación (fila) en el conjunto de datos a los factores latentes. 
AF_train = pd.DataFrame(fa.transform(X_train))
prefijo = "AF_"
AF_train = AF_train.add_prefix(prefijo)
AF_test = pd.DataFrame(fa.transform(X_test))
AF_test = AF_test.add_prefix(prefijo)
AF_train.head()
# Out:
#    AF_0  AF_1  AF_2  AF_3
# 0 -1.15  0.71  0.13 -1.49
# 1 -2.06  0.67  0.16  1.73
# 2  0.57 -0.13  0.66  0.02
# 3  0.74 -0.41 -0.37  0.16
# 4  1.28 -1.29 -0.63  0.46

# %% [markdown]
# <a id="7-4"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Resultados en Gráficos</h3>

# %% [markdown]
# *Normalicemos la variable target*

# %%
# Normalicemos el target 
y_train = df_train['Attrition_Flag']
y_test = df_test['Attrition_Flag']
# Calculo media y desvio
media = y_train.mean()
desvio = np.std(y_train, ddof = 0)
# Genero parámetros con train
df_train['Attrition_Flag_Scaled'] = (df_train['Attrition_Flag'] - media) / desvio
df_test['Attrition_Flag_Scaled'] = (df_test['Attrition_Flag'] - media) / desvio

# %%
# Features escaladas
df_train_scaled = pd.DataFrame(data = X_train)
prefijo = "Scaled_"
df_train_scaled.columns = lista_predictores_4
df_train_scaled.add_prefix(prefijo)
df_train_scaled = df_train_scaled.add_prefix(prefijo)
df_test_scaled = pd.DataFrame(data = X_test)
prefijo = "Scaled_"
df_test_scaled.columns = lista_predictores_4
df_test_scaled = df_test_scaled.add_prefix(prefijo)

# %%
# Uno todo a los dataframes originales
df_train = pd.concat([df_train,df_train_scaled,PCA_train,KPCA_train,AF_train],axis = 1)
df_test = pd.concat([df_test,df_test_scaled,PCA_test,KPCA_test,AF_test],axis = 1)

# %%
# PCA
plt.figure()
sns.scatterplot(data = df_train,
                x = 'PC_0',
                y = 'Attrition_Flag_Scaled',
               label='PC_0', 
               color = '#34EB63',
                alpha = 1)
sns.scatterplot(data = df_train, 
                x = 'PC_1', 
                y = 'Attrition_Flag_Scaled', 
                label = 'PC_1', 
                color = '#AACA0B',
                alpha = 0.75)
sns.scatterplot(data = df_train, 
                x = 'PC_2', 
                y = 'Attrition_Flag_Scaled', 
                label = 'PC_2', 
                color = '#CA7F0B',
                alpha = 0.6)
sns.scatterplot(data = df_train, 
                x = 'PC_3', 
                y = 'Attrition_Flag_Scaled', 
                label = 'PC_3', 
                color = '#CA0B0B',
                alpha = 0.5)
plt.xlabel('Componente Principal')
plt.ylabel('Attrition_Flag')
plt.title('Relación entre componentes y variable target')
# Out:
# Text(0.5, 1.0, 'Relación entre componentes y variable target')

# %%
# Sólo primeros dos componentes 
plt.figure()
sns.scatterplot(data = df_train,
                x = 'PC_0',
                y = 'Attrition_Flag',
               label='PC_0', 
               color = '#34EB63',
                alpha = 1)
sns.scatterplot(data = df_train, 
                x = 'PC_1', 
                y = 'Attrition_Flag', 
                label = 'PC_1', 
                color = '#AACA0B',
                alpha = 0.75)
plt.xlabel('Componente Principal')
plt.ylabel('Attrition_Flag')
plt.title('Relación entre componentes y variable target')
# Out:
# Text(0.5, 1.0, 'Relación entre componentes y variable target')

# %%
# Correlación con el target 
variables_PCA = ['PC_0','PC_1','PC_2','PC_3','Attrition_Flag_Scaled']
variables_final = lista_predictores_4 + variables_PCA
# Calculo matriz de correlación 
matriz_correlacion = df_train[variables_final].corr(method='pearson')
# Selecciono a la variable target para estudiar únicamente correlación con ella 
matriz_correlacion_target = matriz_correlacion['Attrition_Flag_Scaled']
# Calculo valor absoluto, para extraer correlaciones más fuertes independientemente de su sentido 
matriz_correlacion_target = abs(matriz_correlacion_target)
# Menciono columnas que quiero excluir del análisis de correlación 
columnas_a_excluir = ['Attrition_Flag_Scaled']
# Las excluyo del análisis
matriz_correlacion_target = matriz_correlacion_target.drop(columns=columnas_a_excluir, index=columnas_a_excluir)
# Ordeno de mayor a menor correlacion 
matriz_correlacion_target = matriz_correlacion_target.sort_values(ascending=False)
# Grafico el top 20 de variables más correlacionadas
matriz_correlacion_target_graficar = matriz_correlacion_target[0:20]
plt.figure(figsize=(10, 6))  # Tamaño de la figura
plt.barh(matriz_correlacion_target_graficar.index, 
         matriz_correlacion_target_graficar.values,
         color = '#A989D6')
plt.xlabel('Correlación')
plt.title('Correlación con Attrition_Flag_Scaled')
plt.gca().invert_yaxis()  # Invertir el eje Y para mostrar la característica más relevante en la parte superior
plt.show()

# %%
# PCA
plt.figure()
sns.scatterplot(data = df_train,
                x = 'KPC_0',
                y = 'Attrition_Flag_Scaled',
               label='KPC_0', 
               color = '#34EB63',
                alpha = 1)
sns.scatterplot(data = df_train, 
                x = 'KPC_1', 
                y = 'Attrition_Flag_Scaled', 
                label = 'KPC_1', 
                color = '#AACA0B',
                alpha = 0.75)
sns.scatterplot(data = df_train, 
                x = 'KPC_2', 
                y = 'Attrition_Flag_Scaled', 
                label = 'KPC_2', 
                color = '#CA7F0B',
                alpha = 0.6)
sns.scatterplot(data = df_train, 
                x = 'KPC_3', 
                y = 'Attrition_Flag_Scaled', 
                label = 'KPC_3', 
                color = '#CA0B0B',
                alpha = 0.5)
plt.xlabel('Kernel - Componente Principal')
plt.ylabel('Attrition_Flag')
plt.title('Relación entre componentes Kernel y variable target')
# Out:
# Text(0.5, 1.0, 'Relación entre componentes Kernel y variable target')

# %%
# Sólo primeros dos componentes 
plt.figure()
sns.scatterplot(data = df_train,
                x = 'KPC_0',
                y = 'Attrition_Flag_Scaled',
               label='KPC_0', 
               color = '#34EB63',
                alpha = 1)
plt.xlabel('Kernel - Componente Principal')
plt.ylabel('Attrition_Flag')
plt.title('Relación entre componentes Kernel y variable target')
# Out:
# Text(0.5, 1.0, 'Relación entre componentes Kernel y variable target')

# %%
# Correlación con el target 
variables_KPCA = ['KPC_0','KPC_1','KPC_2','KPC_3','Attrition_Flag_Scaled']
variables_final = lista_predictores_4 + variables_KPCA
# Calculo matriz de correlación 
matriz_correlacion = df_train[variables_final].corr(method='pearson')
# Selecciono a la variable target para estudiar únicamente correlación con ella 
matriz_correlacion_target = matriz_correlacion['Attrition_Flag_Scaled']
# Calculo valor absoluto, para extraer correlaciones más fuertes independientemente de su sentido 
matriz_correlacion_target = abs(matriz_correlacion_target)
# Menciono columnas que quiero excluir del análisis de correlación 
columnas_a_excluir = ['Attrition_Flag_Scaled']
# Las excluyo del análisis
matriz_correlacion_target = matriz_correlacion_target.drop(columns=columnas_a_excluir, index=columnas_a_excluir)
# Ordeno de mayor a menor correlacion 
matriz_correlacion_target = matriz_correlacion_target.sort_values(ascending=False)
# Grafico el top 20 de variables más correlacionadas
matriz_correlacion_target_graficar = matriz_correlacion_target[0:20]
plt.figure(figsize=(10, 6))  # Tamaño de la figura
plt.barh(matriz_correlacion_target_graficar.index, 
         matriz_correlacion_target_graficar.values,
         color = '#A989D6')
plt.xlabel('Correlación')
plt.title('Correlación con Attrition_Flag_Scaled')
plt.gca().invert_yaxis()  # Invertir el eje Y para mostrar la característica más relevante en la parte superior
plt.show()

# %%
#Relación entre PC_0 y KPC_0
plt.figure()
sns.scatterplot(data = df_train,
                x = 'PC_0',
                y = 'KPC_0',
                alpha = 0.6)
plt.xlabel('Factor 0')
plt.ylabel('Resto PC_0 Y KPC_0')
plt.title('Relación entre Componentes')
# Out:
# Text(0.5, 1.0, 'Relación entre Componentes')

# %%
# Factores
plt.figure()
sns.scatterplot(data = df_train,
                x = 'AF_0',
                y = 'Attrition_Flag_Scaled',
               label='AF_0', 
               color = '#34EB63',
                alpha = 1)
sns.scatterplot(data = df_train, 
                x = 'AF_1', 
                y = 'Attrition_Flag_Scaled', 
                label = 'AF_1', 
                color = '#AACA0B',
                alpha = 0.75)
sns.scatterplot(data = df_train, 
                x = 'AF_2', 
                y = 'Attrition_Flag_Scaled', 
                label = 'AF_2', 
                color = '#CA7F0B',
                alpha = 0.6)
sns.scatterplot(data = df_train, 
                x = 'AF_3', 
                y = 'Attrition_Flag_Scaled', 
                label = 'AF_3', 
                color = '#CA0B0B',
                alpha = 0.5)
plt.xlabel('Factores')
plt.ylabel('Attrition_Flag')
plt.title('Relación entre Factores y variable target')
# Out:
# Text(0.5, 1.0, 'Relación entre Factores y variable target')

# %%
# Correlación con el target 
variables_AF = ['AF_0','AF_1','AF_2','AF_3','Attrition_Flag_Scaled']
variables_final = lista_predictores_4 + variables_AF
# Calculo matriz de correlación 
matriz_correlacion = df_train[variables_final].corr(method='pearson')
# Selecciono a la variable target para estudiar únicamente correlación con ella 
matriz_correlacion_target = matriz_correlacion['Attrition_Flag_Scaled']
# Calculo valor absoluto, para extraer correlaciones más fuertes independientemente de su sentido 
matriz_correlacion_target = abs(matriz_correlacion_target)
# Menciono columnas que quiero excluir del análisis de correlación 
columnas_a_excluir = ['Attrition_Flag_Scaled']
# Las excluyo del análisis
matriz_correlacion_target = matriz_correlacion_target.drop(columns=columnas_a_excluir, index=columnas_a_excluir)
# Ordeno de mayor a menor correlacion 
matriz_correlacion_target = matriz_correlacion_target.sort_values(ascending=False)
# Grafico el top 20 de variables más correlacionadas
matriz_correlacion_target_graficar = matriz_correlacion_target[0:20]
plt.figure(figsize=(10, 6))  # Tamaño de la figura
plt.barh(matriz_correlacion_target_graficar.index, 
         matriz_correlacion_target_graficar.values,
         color = '#A989D6')
plt.xlabel('Correlación')
plt.title('Correlación con Attrition_Flag_Scaled')
plt.gca().invert_yaxis()  # Invertir el eje Y para mostrar la característica más relevante en la parte superior
plt.show()

# %%
#Relación entre factores 
plt.figure()
sns.scatterplot(data = df_train,
                x = 'AF_0',
                y = 'AF_1',
                label = 'AF_1', 
               color = '#34EB63',
                alpha = 1)
sns.scatterplot(data = df_train, 
                x = 'AF_0', 
                y = 'AF_2', 
                label = 'AF_2', 
                color = '#CA7F0B',
                alpha = 0.6)
sns.scatterplot(data = df_train, 
                x = 'AF_0', 
                y = 'AF_3', 
                label = 'AF_3', 
                color = '#CA0B0B',
                alpha = 0.6)
plt.xlabel('Factor 0')
plt.ylabel('Resto Factores')
plt.title('Relación entre Factores')
# Out:
# Text(0.5, 1.0, 'Relación entre Factores')

# %% [markdown]
# <a id="7-5"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Conclusiones</h3>

# %% [markdown]
# *El análisis de PCA sugiere que la mayoría de la variabilidad de los datos se puede capturar con solo el primer componente principal. Esto podría indicar que algunas de las variables originales son altamente correlacionadas.*
#
# *El análisis de KernelPCA y AF también proporciona información sobre la estructura de los datos y la relevancia de las variables originales en los nuevos componentes generados.*

# %% [markdown]
# <a id="8"></a>
# <h1 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Conclusión Final</h1>

# %% [markdown]
# *Basándonos en el análisis realizado y en los resultados obtenidos del modelo de RandomForest ajustado por hiperparámetros.*

# %%
# Gráfico de comparación para el conjunto de entrenamiento
plt.figure(figsize=(10, 6))
plt.scatter(df_train.index, df_train['Attrition_Flag'], color='blue', label='Real')
plt.scatter(df_train.index, df_train['RF_Predicted_Attrition_Flag'], color='red', marker='x', label='Predicho')
plt.xlabel('Índice de Muestra')
plt.ylabel('Attrition_Flag')
plt.title('Comparación entre Datos Reales y Predichos (Conjunto de Entrenamiento)')
plt.legend()
plt.show()

# Gráfico de comparación para el conjunto de prueba
plt.figure(figsize=(10, 6))
plt.scatter(df_test.index, df_test['Attrition_Flag'], color='blue', label='Real')
plt.scatter(df_test.index, df_test['RF_Predicted_Attrition_Flag'], color='red', marker='x', label='Predicho')
plt.xlabel('Índice de Muestra')
plt.ylabel('Attrition_Flag')
plt.title('Comparación entre Datos Reales y Predichos (Conjunto de Prueba)')
plt.legend()
plt.show()

# %% [markdown]
# <a id="8-1"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Variables Relevantes</h3>

# %% [markdown]
# *Las variables que mostraron ser más relevantes para predecir la retención de clientes fueron:*
#
# *Total_Trans_Amt: El monto total de la transacción en los últimos 12 meses.*<BR>
# *Total_Revolving_Bal: El saldo rotativo total de la tarjeta de crédito.*<BR>
# *Total_Trans_Ct: El recuento total de transacciones en los últimos 12 meses.*<BR>
# *Avg_Utilization_Ratio: El índice de utilización promedio de la tarjeta.*<BR>
# *Credit_Limit: El límite de crédito en la tarjeta de crédito.*<BR>
# *Total_Relationship_Count: El número total de productos en poder del cliente.*<BR>
# *Total_Ct_Chng_Q4_Q1: El cambio en el recuento de transacciones de Q4 sobre Q1.*<BR>
# *Total_Amt_Chng_Q4_Q1: El cambio en el monto de la transacción de Q4 sobre Q1.*<BR>

# %% [markdown]
# <a id="8-2"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Desempeño del Modelo</h3>

# %% [markdown]
# *El modelo RandomForest ajustado por hiperparámetros mostró una precisión del 96.28% en el conjunto de entrenamiento y del 94.03% en el conjunto de prueba. Estos resultados indican que el modelo es capaz de predecir con precisión la retención de clientes en función de las variables seleccionadas.*

# %% [markdown]
# <a id="8-3"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Conclusión</h3>

# %% [markdown]
# *El análisis realizado demuestra que ciertas variables relacionadas con el comportamiento financiero y la actividad del cliente son indicadores clave para predecir la retención de clientes en la industria de servicios financieros. El modelo RandomForest proporciona una herramienta efectiva para identificar a los clientes con mayor probabilidad de retención, lo que permite a las instituciones financieras dirigir estrategias de retención de manera más efectiva.*

# %% [markdown]
# <a id="8-4"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Recomendaciones</h3>

# %% [markdown]
# *Con base en estos hallazgos, se recomienda implementar una campaña de marketing personalizada dirigida a los clientes identificados como propensos a abandonar la institución financiera. Esta campaña podría incluir incentivos especiales, ofertas exclusivas o programas de fidelización diseñados para aumentar la retención de clientes y fortalecer la relación con la institución financiera.*

# %% [markdown]
# <a id="8-5"></a>
# <h3 style="text-align:left;border-radius:8px;font-family:Times;font-variant:small-caps;color:#FFFFFF;background-color:#3300CC;">Resumen</h3>

# %% [markdown]
# *En resumen, el análisis realizado proporciona información valiosa para la toma de decisiones estratégicas en la gestión de la retención de clientes en la industria de servicios financieros, lo que puede ayudar a mejorar la satisfacción del cliente, aumentar la lealtad y, en última instancia, impulsar el crecimiento y la rentabilidad del negocio.*
